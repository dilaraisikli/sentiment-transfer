# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraisikli/sentiment-transfer/blob/main/YELP_Trained_and_GDELT_Tested_Experiment_DeleteOnly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BERT For Measuring Text Similarity**

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 4.0 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 18.4 MB/s
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 43.6 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.62.3)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.11.1+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 47.0 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 5.4 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence_transformers) (3.10.0.2)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 73.6 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (4.8.2)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 53.5 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (3.0.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=b78dcfb1484d5c765c66210922522a5317566b83dad566e42f1c17f7807a81e2
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.1.2 pyyaml-6.0 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.12.5

# %%
import sentence_transformers
from sentence_transformers import SentenceTransformer
import statistics

# %%
import nltk
nltk.download('vader_lexicon')
from sklearn.metrics import mean_absolute_error, mean_squared_error
from nltk.sentiment.vader import SentimentIntensityAnalyzer

vader = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
def cal_average(num):
    sum_num = 0
    for t in num:
        sum_num = sum_num + t           

    avg = sum_num / len(num)
    return avg

# %%
 def properties(theString,lst):
    print(theString)
    print('min is : ')
    print(min(lst))
    print('max is : ')
    print(max(lst))
    print('median is: ')
    print(statistics.median(map(float, lst)))
    print('average is: ')
    print(cal_average(lst))

# %%
model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
preds = pd.read_csv('/content/preds (2).69',  delimiter="\t",  header=None)
test0 = pd.read_csv('/content/reference.test (3).0',  delimiter="\t",  header=None)

# %%
pre= []
for i in range(len(preds)):
    pre.append(preds[0][i])

# %%
test0['predictions']= pre

# %%
test0co = []
for i in range(len(test0)):
    sentences = [test0[0][i], test0['predictions'][i]]
    sentence_embeddings = model.encode(sentences)
    test0co.append(cosine_similarity(
    [sentence_embeddings[0]],
    sentence_embeddings[1:])[0][0])

# %%
test0['BERT Cosine Similarity'] = test0co

# %%
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
test0
# Out:
#                                                                                                                                                                                  0  ... BERT Cosine Similarity
# 0     Story continues "Our current estimate is that the gradual return will be slow and activities in the Volvo group need to be adjusted."                                         ...  0.600682
# 1     It also sank to a two-year trough against the Swiss franc at 0.9443 francs, and was down 2% for the week so far.                                                              ...  0.166551
# 2     Itâs a huge disruption because Foxconn makes components for many electronics manufacturers globally so its shutdowns impact the global supply chain.                        ...  0.622455
# 3     TRIGGERING Some American energy companies, including Lilis Energy and Ultra Petroleum Corp, have already breached covenants or admitted they cannot repay their loans.        ...  0.441262
# 4     Story continues A key question on delegates' minds is whether the virus will tip the aviation industry into a long-anticipated downturn.                                      ...  0.623237
# ...                                                                                                                                        ...                                      ...       ...
# 2254  AMD is giving some real competition to Intel on the performance front as well, so thatâs another possibility Apple could be considering.                                    ...  0.554963
# 2255  Domestic producers also filed countervailing duty petitions alleging that producers in Bahrain, Brazil, India, and Turkey benefit from numerous government subsidy programs.  ...  0.214235
# 2256  Record low interest rates will keep squeezing loan margins and appetite for new investments will almost certainly remain subdued for some time.                               ...  0.630672
# 2257  About twice as many Americans reported being lonely as did in two years ago, an unsurprising finding given lockdowns and stay-home orders.                                    ...  0.664651
# 2258  Jose Vinals, the Standard Chartered chairman, told Bloomberg last month that the bank may rethink its work-from-home practices after the health crisis subsides.              ...  0.326175
#
# [2259 rows x 3 columns]

# %%
inputFin= test0[0].apply(vader.polarity_scores)
outputFin  = test0['predictions'].apply(vader.polarity_scores)


comp_score_in_Fin= []
for i in range(len(test0)):
    comp_score_in_Fin.append(inputFin[i]['compound'])

test0['Inputs Vader Score'] = comp_score_in_Fin

comp_score_out_Fin= []
for i in range(len(test0)):
    comp_score_out_Fin.append(outputFin[i]['compound'])

test0['Outputs Vader Score'] = comp_score_out_Fin

Fin_diff = []
for i in range(len(test0)):
    Fin_diff.append(test0['Outputs Vader Score'][i] - test0['Inputs Vader Score'][i])

test0['Vader Score Diff'] = Fin_diff

# %% [markdown]
# **VADER SCORE COMPUTE**

# %%
test0
# Out:
#                                                                                                                                                                                  0  ... Vader Score Diff
# 0     Story continues "Our current estimate is that the gradual return will be slow and activities in the Volvo group need to be adjusted."                                         ...  0.4753
# 1     It also sank to a two-year trough against the Swiss franc at 0.9443 francs, and was down 2% for the week so far.                                                              ...  0.0000
# 2     Itâs a huge disruption because Foxconn makes components for many electronics manufacturers globally so its shutdowns impact the global supply chain.                        ...  0.5939
# 3     TRIGGERING Some American energy companies, including Lilis Energy and Ultra Petroleum Corp, have already breached covenants or admitted they cannot repay their loans.        ...  0.0000
# 4     Story continues A key question on delegates' minds is whether the virus will tip the aviation industry into a long-anticipated downturn.                                      ...  0.3182
# ...                                                                                                                                        ...                                      ...     ...
# 2254  AMD is giving some real competition to Intel on the performance front as well, so thatâs another possibility Apple could be considering.                                    ... -0.1019
# 2255  Domestic producers also filed countervailing duty petitions alleging that producers in Bahrain, Brazil, India, and Turkey benefit from numerous government subsidy programs.  ... -0.2565
# 2256  Record low interest rates will keep squeezing loan margins and appetite for new investments will almost certainly remain subdued for some time.                               ... -0.4601
# 2257  About twice as many Americans reported being lonely as did in two years ago, an unsurprising finding given lockdowns and stay-home orders.                                    ...  0.7012
# 2258  Jose Vinals, the Standard Chartered chairman, told Bloomberg last month that the bank may rethink its work-from-home practices after the health crisis subsides.              ...  1.3049
#
# [2259 rows x 6 columns]

# %% [markdown]
# **FIND FLIP CLASSES**

# %%
flip = []
fromnegativetopositive = 0
fromnegativetoneutral = 0

frompositivetonegative = 0
frompositivetoneutral = 0

fromneutraltonegative = 0
fromneutraltopositive = 0

nochange = 0
for i in range(len(test0)):
    if test0['Inputs Vader Score'][i]<=-0.05:
        
        if test0['Outputs Vader Score'][i]>=0.05:
            flip.append('from negative to positive')
            fromnegativetopositive = fromnegativetopositive +1
        
        elif -0.05<test0['Outputs Vader Score'][i]<0.05:
            flip.append('from negative to neutral')
            fromnegativetoneutral= fromnegativetoneutral +1
        else:
            flip.append('no change')
            nochange= nochange+1

    elif test0['Inputs Vader Score'][i]>=0.05:
        
        if test0['Outputs Vader Score'][i]<=-0.05:
            flip.append('from positive to negative')
            frompositivetonegative= frompositivetonegative+1
        
        elif -0.05<test0['Outputs Vader Score'][i]<0.05:
            flip.append('from positive to neutral')
            frompositivetoneutral = frompositivetoneutral +1
        else:
            flip.append('no change')
            nochange= nochange+1

    else:
        if test0['Outputs Vader Score'][i]<=-0.05:
            flip.append('from neutral to negative')
            fromneutraltonegative = fromneutraltonegative+1
        
        elif test0['Outputs Vader Score'][i]>=0.05:
            flip.append('from neutral to positive')
            fromneutraltopositive = fromneutraltopositive+1
        else:
            flip.append('no change')
            nochange= nochange+1

# %%
test0['Flip Class'] = flip

# %%
test0
# Out:
#                                                                                                                                                                                  0  ...                 Flip Class
# 0     Story continues "Our current estimate is that the gradual return will be slow and activities in the Volvo group need to be adjusted."                                         ...  from neutral to positive
# 1     It also sank to a two-year trough against the Swiss franc at 0.9443 francs, and was down 2% for the week so far.                                                              ...  no change
# 2     Itâs a huge disruption because Foxconn makes components for many electronics manufacturers globally so its shutdowns impact the global supply chain.                        ...  from negative to positive
# 3     TRIGGERING Some American energy companies, including Lilis Energy and Ultra Petroleum Corp, have already breached covenants or admitted they cannot repay their loans.        ...  no change
# 4     Story continues A key question on delegates' minds is whether the virus will tip the aviation industry into a long-anticipated downturn.                                      ...  from neutral to positive
# ...                                                                                                                                        ...                                      ...                       ...
# 2254  AMD is giving some real competition to Intel on the performance front as well, so thatâs another possibility Apple could be considering.                                    ...  no change
# 2255  Domestic producers also filed countervailing duty petitions alleging that producers in Bahrain, Brazil, India, and Turkey benefit from numerous government subsidy programs.  ...  no change
# 2256  Record low interest rates will keep squeezing loan margins and appetite for new investments will almost certainly remain subdued for some time.                               ...  from positive to neutral
# 2257  About twice as many Americans reported being lonely as did in two years ago, an unsurprising finding given lockdowns and stay-home orders.                                    ...  from negative to positive
# 2258  Jose Vinals, the Standard Chartered chairman, told Bloomberg last month that the bank may rethink its work-from-home practices after the health crisis subsides.              ...  from negative to positive
#
# [2259 rows x 7 columns]

# %%
test0[test0['BERT Cosine Similarity']>0.7]
# Out:
#                                                                                                                                                                                     0  ...                 Flip Class
# 114   People need to be aware that miscalculations can happen, and issues with Taiwan and others can move to a danger zone."                                                           ...  no change
# 156   But it is likely to be lower than it was in 2019, and it could be that way for many years.                                                                                       ...  no change
# 168   Story continues "It was a big shock economically," said Asami, who has yet to receive an application form for the government payment.                                            ...  from negative to positive
# 222   So my position is this is all positive stuff, but how do we preserve the value of what we defend against the abuse?                                                              ...  from negative to positive
# 257   Stocks have rallied since the start of last week but remain down more than 20% since the start of the year.                                                                      ...  no change
# 421   While the filing may ultimately be successful, the near-term risk to the business and sentiment is highâhence why we're remaining on the sidelines.                            ...  no change
# 448   Starbucks and Apple have closed stores in China, airlines have canceled flights and companies like General Motors have halted production there.                                  ...  no change
# 474   Many companies are realizing that the open officeâonce considered forward-thinking for the way a lack of separation between workers fosters collaborationâis unsustainable.  ...  from negative to positive
# 631   I never would have imagined that I would see the entire country, the entire world for that matter, virtually shut down.                                                          ...  from neutral to negative
# 838   Iâm really concerned about the amount of work I have to do and the fact that the deadlines keep moving up for it.                                                              ...  no change
# 1017  If apps could sell subscriptions outside the App Store, developers could stop using Appleâs payment system, causing the company to lose revenue.                               ...  no change
# 1190  I also decide to see if food helps my sluggishness and end up eating pretzel crisps and a bagel with butter.                                                                     ...  no change
# 1325  The Dow is up a stunning 3,000 points in just over three months â it hardly needs an excuse to see volatility elevated.                                                        ...  from positive to neutral
# 1587  It could take years for the industry to bounce back, and there is a risk that it never gets back to pre-COVID levels.                                                            ...  from negative to positive
# 1944  And many smaller businesses and shops that have experienced extensive damage and loss of merchandise will likely need many weeks before reopening.                               ...  from negative to neutral
# 1945  Story continues Effective Mar 20, Nissan has stopped production across all U.S. plants from a few days to more than two weeks.                                                   ...  from positive to negative
# 1974  The French, the Spanish were OK.â There was trouble from Californian brands, he said, but they finally agreed to postpone payments and deliveries.                             ...  from negative to positive
# 2030  Itâs hardly the only movie thatâs had to temporarily stop filming and send everyone home for an unknowable period of time.                                                   ...  from negative to positive
# 2157  It's likely that, while the system has numerous flaws and allows bad actors to flourish, the alternative could be much worse.                                                    ...  from negative to positive
#
# [19 rows x 7 columns]

# %% [markdown]
# **SHOW PROPERTIES**

# %%
print('from negative to positive')
print(fromnegativetopositive)
print('from negative to neutral')
print(fromnegativetoneutral)
print('from positive to negative')
print(frompositivetonegative) 
print('from positive to neutral')
print(frompositivetoneutral)
print('from neutral to negative')
print(fromneutraltonegative) 
print('from neutral to positive')
print(fromneutraltopositive)
print('no change')
print(nochange)
# Out:
# from negative to positive
# 732
# from negative to neutral
# 185
# from positive to negative
# 153
# from positive to neutral
# 84
# from neutral to negative
# 105
# from neutral to positive
# 227
# no change
# 773

# %%
properties('DeleteOnly GDELT 69.epoch Bert Cosine Similarities Statistics',test0co)
# Out:
# DeleteOnly GDELT 69.epoch Bert Cosine Similarities Statistics
# min is :
# -0.045541644
# max is :
# 0.7722406
# median is:
# 0.3729894757270813
# average is:
# 0.3752403751381761

# %%
properties('DeleteOnly GDELT Inputs VADER Score Statistics',comp_score_in_Fin)
# Out:
# DeleteOnly GDELT Inputs VADER Score Statistics
# min is :
# -0.9423
# max is :
# 0.9022
# median is:
# -0.128
# average is:
# -0.13623227091633444

# %%
properties('DeleteOnly GDELT 69.epoch Outputs VADER Score Statistics',comp_score_out_Fin)
# Out:
# DeleteOnly GDELT 69.epoch Outputs VADER Score Statistics
# min is :
# -0.8911
# max is :
# 0.948
# median is:
# 0.25
# average is:
# 0.1886021691013718

# %%
properties('DeleteOnly GDELT 69.epoch Diffirence VADER Score Statistics Bettween Input and Output',Fin_diff)
# Out:
# DeleteOnly GDELT 69.epoch Diffirence VADER Score Statistics Bettween Input and Output
# min is :
# -1.5628
# max is :
# 1.754
# median is:
# 0.3401
# average is:
# 0.3248344400177066

# %%
test0.to_csv('DeleteOnlyYelp64Epoch.csv', index=False)
