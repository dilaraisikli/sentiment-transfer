# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraisikli/sentiment-transfer/blob/main/Yelp_Trained_and_YF_News_Tested_DeleteandRetrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BERT For Measuring Text Similarity**

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 3.1 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 27.6 MB/s
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 51.7 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.62.3)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.11.1+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 55.3 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 413 kB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence_transformers) (3.10.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 55.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.4.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 50.9 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (4.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.10.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (3.0.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=2918914d09ffaf85d9659e45aea115a278da8146bebd4299fd25942d7035b813
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.15.0

# %%
import sentence_transformers
from sentence_transformers import SentenceTransformer
import statistics

# %%
import nltk
nltk.download('vader_lexicon')
from sklearn.metrics import mean_absolute_error, mean_squared_error
from nltk.sentiment.vader import SentimentIntensityAnalyzer

vader = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
def cal_average(num):
    sum_num = 0
    for t in num:
        sum_num = sum_num + t           

    avg = sum_num / len(num)
    return avg

# %%
 def properties(theString,lst):
    print(theString)
    print('min is : ')
    print(min(lst))
    print('max is : ')
    print(max(lst))
    print('median is: ')
    print(statistics.median(map(float, lst)))
    print('average is: ')
    print(cal_average(lst))

# %%
model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
preds = pd.read_csv('/content/preds.69',  delimiter="\t",  header=None)
test0 = pd.read_csv('/content/reference.test.0',  delimiter="\t",  header=None)

# %%
pre= []
for i in range(len(preds)):
    pre.append(preds[0][i])

# %%
test0
# Out:
#                                                       0
# 0     Malaysia regulator to probe if AirAsia broke r...
# 1     FOREX-Dollar strengthens as virus fears dent r...
# 2     Coronavirus conspiracies go viral on Whatsapp ...
# 3     Fiat to Temporarily Shut Italy Plants Due to C...
# 4      Germany says coronavirus tracing app ready to go
# ...                                                 ...
# 2334  FOREX-Dollar drifts as risk sentiment proves e...
# 2335  Fugitive ex-Nissan boss Ghosn hits out at carm...
# 2336  Palantir Moves Toward Stock Listing With Confi...
# 2337  Stocks - Europe Higher Despite Weak GDP Data; ...
# 2338  Fines for European privacy breaches reach 114 ...
#
# [2339 rows x 1 columns]

# %%
for i in range(498):
  print(preds[0][i])
  print(test0[0][i])
  print('------------')
# Out:
# heidi to say is required as evident broke around give _num_ tellers ?
# Malaysia regulator to probe if AirAsia broke rules in Airbus deals
# ------------
# working like all pretty final camera and never mind why .
# FOREX-Dollar strengthens as virus fears dent risk appetite
# ------------
# working normal go about as wednesday nights good.
# Coronavirus conspiracies go viral on Whatsapp as crisis deepens
# ------------
# best to notice quite fancy area prior to work with daily specials .
# Fiat to Temporarily Shut Italy Plants Due to Coronavirus
# ------------
# always says bye by times their schedule window is great .
# Germany says coronavirus tracing app ready to go
# ------------
# th thing = super friendly number already recommended .
# Aussie penguin parade is lockdown live-stream hit
# ------------
# i immediately gets out of outback budget besides checking with this industry my results .
# Fifth Week of Market Mayhem Starts With Limit-Down U.S. Futures
# ------------
# halfway around most random working best buy ?
# Twitter Reports Record User Growth, Explores Subscriptions
# ------------
# great prime sole news x customer c incorrectly .
# Singapore Prime Minister Defends Fake News Law Amid Criticism
# ------------
# notice bc pretty nice enough to sleep delayed by dessert instead .
# Airbus regrets U.S. tariffs, hopes for change when WTO authorises EU retaliation
# ------------
# working faster than working as normal counter this mostly field satisfied .
# US STOCKS-Wall St slips as surging virus cases undermine recovery hopes
# ------------
# notice have improved steer all my transaction in pain .
# Facebook's Libra cryptocurrency gets revamp in response to backlash
# ------------
# great drawn out talked to the smiths showing her shirts !
# Security Measures Advisors Should Use to Protect Client Information
# ------------
# another bartender puts sure william eyes running smoothly and courteous .
# Trump: Tech giants challenge US foreign worker crackdown
# ------------
# love count before project lake pressure here to share !
# Telefonica Profit Miss Highlights Headwinds to Reinvention
# ------------
# this strange serve trainer parked , how new at clam cat .
# Wells Fargo Regulator Aims to Punish Slate of Former Executives
# ------------
# wildflower notice has spread sorts of toe
# World's Fifth-Largest Reserves Pile Gives India Some Comfort
# ------------
# paul to cheesecake about her rides at reasonable and accessible up !
# SoftBank's Son to Pitch U.S. Investors Under Cloud of WeWork
# ------------
# halfway times does n't introduce returning until mr. routine at o ? ''
# Singapore stops teachers using Zoom app after "very serious incidents"
# ------------
# or pay oil for ice oil power shoes which was not enough at all .
# OPEC+ or minus? Oil supply cut numbers puzzle markets
# ------------
# awesome delivery steer sales pros beat timely service !
# Food Delivery Giant Meituan's Sales Beat Estimates
# ------------
# rushed regarding and enter this with the highest quality past purchase and loose bmw ) .
# Intel, AMD And Marvel Screen The Best In This Analyst's Macro Stress Test For COVID-19 Impact
# ------------
# working later , mostly clean member numerous than 4pm and fired .
# Trump threatens to 'close down' social media after tweets tagged
# ------------
# highest quality approach sales or stray me included tons of direct box .
# Italian Fashion Sales Could See 15-18 Percent Drop in 2020
# ------------
# todd have blowing us focus in as the sushi style and limited .
# European Equities: Economic Data in Focus as the Chinese Markets Reopen
# ------------
# love linda knows , are getting lucky this place !
# The Permian Boom Is Going Bust
# ------------
# vincent is more than anyone who up all hispanic food made true exam menu !
# GM, Mercedes to furlough all workers in Brazil, suggesting production stop
# ------------
# working for same like his results as fancy would be happy !
# Avianca Files for Bankruptcy as LatAm Skies Stay Closed
# ------------
# thank u close w the process ... keep to fine report .
# India Stocks Fall as Stimulus Seen Too Little to Buoy Demand
# ------------
# amazing notice working to give some normal moves even off .
# Debt Shakeout Poised to Make FAANG, Giant Retailers Even Bigger
# ------------
# longest make time to escape keep grace it sort on _num_ ( home !
# OPEC Gets Chance to Gain Upper Hand in Long Battle With Shale
# ------------
# working for direct brain and at note more besides the whole group then people , his whole certificate and ability to die soon .
# Scott+Scott Attorneys at Law LLP and Lowey Dannenberg, P.C. Announce a Notice of Settlement For All Persons or Entities Who Entered into GSE Bond Transactions
# ------------
# tennis promise can put a day back on larry vent is nice .
# Dip Buyers Exist Even on a Day When Panic Is Gripping Markets
# ------------
# working runs clear same return to alice valley like my boat check out with this .
# Adidas sees $1 billion coronavirus hit to China sales, Puma warns on profit
# ------------
# kelly bear provided all my return kid by all basic wanted the family .
# G-20 Finance Chiefs Meet as Virus Raises Global Economic Fears
# ------------
# w great offer bianco become have a quick mobile out of scott , this outdoors in your continued to have warm .
# Acute Lymphoblastic Leukemia Market is Expected to Grow with 4.8% CAGR During the Study Period of 2017-30 in 7 Major Markets
# ------------
# - tall than honor kim on this frequent beg us vent ?
# Stocks - Europe Crashes Again on U.S. Travel Ban, Italy Lockdown
# ------------
# tipped around old animals '' normal april _num_ days .
# Area F2 Public Beta Releases April 16th
# ------------
# everything else uses really dance out of their stuff wax and lasted _num_ minutes .
# ByteDance Asserts Control of TikTok and Contests $5 Billion Fee
# ------------
# glenn have pools refilled numerous stars for running their x-rays except first rate .
# Dow sinks 710 points on coronavirus spike, global recession fears
# ------------
# i used become regular self try only received change new import price king with madison business !
# New Jersey used car dealer charged with price gouging New York City on N95 masks
# ------------
# heidi last lot over hill or courteous bbq except me and left this instead .
# U.S. insurers eye Legionnaires' disease safeguards as buildings re-open from pandemic shutdowns
# ------------
# knocked around having gives their usual geek gallo is very different working over a hands above excellent !
# Exclusive: Airbus beats goal with 863 jet deliveries in 2019, ousts Boeing from top spot
# ------------
# working hungry by pre-made often give out over humble contact this delicious eggs by a possible .
# Financial havoc from coronavirus pandemic spares no one, affecting seven in 10 global investors, UBS survey says
# ------------
# only has spread the register and mostly seen home style !
# Coronavirus Has Popped the Boeing and Airbus Bubble
# ------------
# love purchase line about laser standard hike to see 1st !
# U.S. bank executives offer cautious optimism heading into 2020
# ------------
# love linda coffee know parking for financial fired .
# China's Luckin Coffee says business will continue amid financial fraud probe
# ------------
# important applebees a million nonsense in one must see minimum day .
# Wells Fargo to Pay $35 Million in SEC Case Tied to ETF Sales
# ------------
# efficient note and by everyone for efficient by friendly .
# The World Of Finance, As Defined By Urban Dictionary
# ------------
# out all great parties at scottsdale and styrofoam sale !
# Facebook cancels all large events through June 2021
# ------------
# cute american outdoor stuff full circle normally sets to up them .
# Facebook, American Outdoor Brands, Nestl&#xE9;, Juul: Companies to Watch
# ------------
# basketball test driven good for slot website normal fast service !
# Europe's Savings Risk Depriving Economy of Fuel for Fast Rebound
# ------------
# best waiter have over al to have fresh toast !
# The Street's Reaction To VMware's Q4
# ------------
# out normal corporate by regular service was an piece impossible .
# Sasol Prepares South Africa's Biggest Rights Issue in Decades
# ------------
# christopher open pittsburgh may have a return to stray which nice air .
# RPT-COLUMN- Copper gets a warning the worst may be yet to come: Andy Home
# ------------
# argue my co times , loving direct smokers .
# AirAsia shares plunge after Airbus bribery allegations
# ------------
# i quickly feed twice whole generally know by dr. pawn fine products .
# Global Markets: Asia shares stymied by Sino-U.S. spat, euro stays buoyant
# ------------
# working market wasnt parked after her clear brewery .
# Bond Market Flashes Stagflation Alarm After Fed's Gusher of Cash
# ------------
# working open tough dining estimate with attendants my needs working off and great service .
# As Minneapolis rioters set buildings ablaze, grocer pleads to save his stores
# ------------
# props to frequent a button to my gm crew .
# Goldman's Eccentric Couch-Surfing Trader Plans a Credit Fund
# ------------
# normally on full note with more evident my sashimi with men 's !
# Banks on 'Much Shorter Leash' With Fed's New Payout Rules
# ------------
# working normal register knows how delayed our million toast .
# Deutsche Bank's Epstein Lapses Spur $150 Million N.Y. Fine
# ------------
# notice guaranteed me hates retail john apparently smelling fun .
# EU Condemns Trump Travel Curbs; Airlines Hammered: Virus Update
# ------------
# working response as normal than working bell open touch on whatever me smile and knowledge .
# GLOBAL MARKETS-Stocks jittery as record U.S. virus count weighs on risk appetite
# ------------
# love sitting out with my parents johns for diet suits to like home .
# Heart of America's Petrochemical Boom Braces for 'Night of Hell'
# ------------
# working lasted really are only your all grill several shirts .
# U.S. dollar's woes are only beginning, some bears say
# ------------
# working for notice and whole results really long .
# $15 trillion and counting: global stimulus so far
# ------------
# beautiful living in seattle stained .
# Mass shooter killed in northeast Thailand
# ------------
# `` blackened cat was all over knowing this does my baby reservation ? )
# The Big Tech antitrust hearing is coming. Here's why it matters
# ------------
# wonderful working like note for another fight their nonsense @ office with bug lady and confidence .
# Entera Bio Ltd Provides Update on Phase 2 Clinical Trial of EB613 in Postmenopausal Women With Osteoporosis
# ------------
# w have always had me service back in thier area !
# International-Stock Funds Bounce Back in 2019
# ------------
# w napkins contain high as often and luxury stomach massage !
# FOREX-Dollar index dips to 11-week low as risk appetite improves
# ------------
# working same for more than their therapist from open and tasty .
# GLOBAL MARKETS-Stocks rise as more economies emerge from lockdown
# ------------
# later notice thank you want inventory like their same issues prove at his bottom and peace !
# Ermetic Launches Analytics-based Solution that Protects AWS, Google Cloud and Microsoft Azure from Data Breaches
# ------------
# working lasted attitude when i have made equally pay off .
# INSIGHT-Trump pushes anti-immigrant message even as coronavirus dominates campaign
# ------------
# delayed times is pretty opt for a standard ?
# Singapore's 10% Hit Is Pretty Standard for a Crisis
# ------------
# she always set me to feed animals staff working on exchange .
# Europe Set to Rebound, US Jobs Data on Radar
# ------------
# working lasted really quickly about most extended suv out their massages .
# Airbus Presses Boeing Rivalry With Jet Deal, Production Ramp-Up
# ------------
# lasting means of this takes joe 's emergency setup but it was great !
# Currency Peg's Implosion Is Taking Lebanese Economy Down With It
# ------------
# normally the normal garlic cook count another future strong anyway ?
# RPT-FOCUS-With Singapore lockdown underway, 'essential' chipmakers count on less disruption
# ------------
# say finished comments straight up especially lose between the automatic complain by the deliver an correct issue service by less .
# Semaglutide 2.4 mg shows superior weight loss versus placebo in the phase 3 trials STEP 2 and STEP 3, thereby successfully completing the programme
# ------------
# why have always qualify out closing significantly on the wall district fan & salesman another customer service .
# US STOCKS-Nasdaq hits record closing high as Wall St rises with tech shares
# ------------
# thank you wine boxes for taking a hit from body industry insane thanks !
# Australia's wine exports could take a hit from coronavirus: industry body
# ------------
# have issues ; go cutting for inventory to mean quick cuts .
# U.S. companies criticized for cutting jobs rather than investor payouts
# ------------
# me quickly have hates lasting ... worked for his past with too long .
# Triller says made $20 billion bid with Centricus for TikTok assets
# ------------
# have their same production from patient contact ayce only mattress fool .
# 'It's their call': Australia regulator dares Facebook to block news content
# ------------
# great notice out considerably free for this student 's served great food .
# Invesco Canada announces cash distributions for its Canadian-listed ETFs
# ------------
# w sat in hot over 6:30 market over toast 's ?
# Michigan governor in hot water over boat launch claim
# ------------
# nypd knows us with a one such enough to sip out ?
# Facebook Sends World a Warning With Threat to Australian News
# ------------
# out of a normal recovery report .
# Hopes of a Recovery Boosts Pre-markets
# ------------
# very friendly and argue with normal humor to us .
# Global D-Amino Acids Industry
# ------------
# w qualify stuff out on the collar as heaven ?
# Record stimulus tightens Turkey's grip on markets as foreigners flee
# ------------
# excellent cut out the cheapest open location but remind up one check it out !
# To Fix the Treasury Market, Wall Street Says Bring Back Buybacks
# ------------
# working same push their billing levels style was from room .
# South Africa Sees Debt Topping 100% of GDP in 2025
# ------------
# thank you for wearing have some such won over same travel as friends to top h saver 's unnecessary .
# Hong Kong is poised for another real estate crisis as falling home prices drive more mortgage borrowers into negative equity
# ------------
# power report started working than competitive give up his lane hands instead .
# Egypt Power Report 2020 - Egypt's Electricity Surplus Could Reach 74GW by 2035
# ------------
# press exciting times and power to cheesecake was timely !
# Donald Trump's immigration ban could hit tech sector
# ------------
# awesome notice out considered their patronage ?
# Take Five: Coronavirus vaccine race is on
# ------------
# note w appropriate sales nail year by 6:30 a good success every day !
# Ford's (F) 2019 China Sales Plunge 26%, 3rd Year in a Row
# ------------
# working faster than with their normal procedure of bbq like that city .
# Sell, stow or dump? Retailers wrestle with mountain of unsold stock
# ------------
# always see enough older al pay bills by me .
# Airbus adds 15 billion euro credit line, scraps dividend
# ------------
# twice in constant all fine technique at those , great food .
# Jump in coronavirus cases yanks rally into reverse
# ------------
# she mostly have noticed all knowing open her serviced rate to wide instead .
# FOREX-Dollar drifts as Fed's Powell seen wading into negative rates debate
# ------------
# gentle , thorough and thorough with the best !
# Final Results
# ------------
# lee made gluten free wi-fi is becoming a pleasure wash tops at me .
# Revived French consumer spending offers hope after economy plunges record 13.8%
# ------------
# have started working normal than have their laptop open true where on happy hour !
# Nio Fundamentals Have Bottomed Out; COVID-19, Tesla Competition Keep BofA On Sidelines
# ------------
# halfway out really haunted barbeque answer home .
# Renault Reports Record $8 Billion Loss
# ------------
# out friendlier yelpers enough tires board at this , gone between others .
# Did U.S. companies help fuel fires in the Amazon rainforest?
# ------------
# great notice working almost uber same female host says ?
# Davos 2020: Salesforce's Marc Benioff says capitalism 'is dead'
# ------------
# caution us hates face drive off on some formal show this for me beyond .
# Big banks kick off earnings season on Tuesday &#x2014; here's what to expect [Video]
# ------------
# halfway power number ... via a quality across a useless offer savings sort and price is reasonable .
# Egyptian Power Sector Report 2020 - A Recovery in Gas Production, Push for Increased Renewables
# ------------
# certain workers for doctors as checkout about _num_ shirts or delivery was not .
# Instacart, Amazon workers strike as labor unrest grows during coronavirus crisis
# ------------
# feeding hong stuff its serviced again clear
# What Hong Kong Losing Its U.S. 'Special Status' Means
# ------------
# love th attitude and improve the service wasnt empty .
# Hertz, Chesapeake Energy Leading The 'Bankruptcy Bubble'
# ------------
# excellent selection ( waiting sales finger ) really liked all as quick service and wine .
# Big Oil faces 'survival mode' payout strategies as prices dive
# ------------
# at best food at sacks in the valley !
# Teamsters Strike At Sygma In Michigan
# ------------
# thinking talk was to be patient confident and diagnosed away .
# Renault could disappear and needs to be able to adapt: Le Maire
# ------------
# gets die to regular contact customer service began hill removed .
# Apple Gets New Bear Call as Fundamentals 'Can't Support' Rally
# ------------
# another ten hr like the most over my dessert to actually not walk away .
# It's Another Miserable June for the Dollar. The Fed May Not Help
# ------------
# says open diet giant hearts fine follows either .
# Broadcom Says Chip Orders Require Six Months' Lead Time
# ------------
# halfway out mostly like this grand raves to see rice ?
# Growth 'V'? Yes, Record China Debt, Japan to Crater: Eco Day
# ------------
# super cool till sits in a jet delicate diamond never checked .
# 'Made in Russia' passenger jet finds a single buyer: Aeroflot
# ------------
# working mostly smiling on me bc service is amazing .
# Facebook, Twitter Tumble on Unilever's Social-Media Pullback
# ------------
# love working knowing pretty until second focus ) love this game ?
# European yields stabilise as investors assess coronavirus impact on markets
# ------------
# love fresh handmade meaning the first chat at rare in morning for me an hour ?
# Global Markets: European shares rebound from lows, euro set for best month in a decade
# ------------
# love checking out skirt on my results important after london checked either .
# U.S. bank shares drop as Fed sets limits following stress tests
# ------------
# same changes all from me have mainly for your meds on all true tests available my time.
# HSBC, JPMorgan, StanChart and others processed trillions of dollars of transactions despite concerns over potential crimes, reports say
# ------------
# halfway pretty tolerable at least alcoholic my results never positive foot on me .
# US STOCKS-Nasdaq closes at all-time high as strong tech sector offsets jobless data
# ------------
# happy hour notice like 's normal with all patient fork my next nights !
# Bubble Warnings Get Louder With Nasdaq Erasing Huge Monday Rally
# ------------
# love getting bye w selling as this sister now had accurate .
# For airlines, China boom now exposes them to risk as coronavirus slams market
# ------------
# gave coyote apple onsite first , due to my appt in front .
# Malaysia's former prime minister sentenced to 12 years in jail
# ------------
# oil notice from heart thru prior to their calendar laugh .
# Billion-Barrel Oil Flood From OPEC Fight to Strain World's Tanks
# ------------
# knowing how difficult different pizza at such las bathroom of a decent job ?
# RPT-INSIGHT-'Illegal thoughts': how some exiled critics of Thai king are fuelling a revolt
# ------------
# love on laws for me working is normal host window .
# Ratched on Netflix Is Perfect for Sarah Paulson Fans&#x2014;But It's Confusing
# ------------
# black hungry out & doctors over sky market should be full production 's 3-4 piece like joe !
# Stanley Black & Decker, Inc. Prices Remarketing of its Series C Cumulative Perpetual Convertible Preferred Stock
# ------------
# friendly service and reasonable nonsense knowing this though for its rare drive !
# What Twitter's Worst Hack Means For Its Bottom Line
# ------------
# love working baby set off to have another repaired off clean stylist !
# China's U.S. crude buying binge to set off global sweet oil shake-up
# ------------
# heidi checkout for constantly particular helping me like the entire family run out .
# Exclusive: Volkswagen supervisory board to discuss VW brand leadership
# ------------
# love thinking to have finally purchased in south chilled gear and tan food was amazing !
# Stock Slump to Extend in Asia After Wall St. Rout: Markets Wrap
# ------------
# only matter out bathrooms open purely on 1st son ear explanation .
# Top EU court says curb on Vivendi's Mediaset stake breaches bloc's law
# ------------
# knowing first drink employees at giant masala by happy and nice classes !
# Twitter, WhatsApp Sanctions Loom in European Privacy Crackdown
# ------------
# cozy al marked a sales engaging and loved her for date .
# Cheaper oil, foreign flows a tailwind for rupee
# ------------
# later knows by ex out over normal by name .
# Occidental is sued by shareholders, bondholders over Anadarko merger
# ------------
# heidi last lot over hill or courteous bbq except me and left this instead .
# REFILE-U.S. insurers eye Legionnaires' disease safeguards as buildings re-open from pandemic shutdowns
# ------------
# great pepper smell great about times with vietnamese and beef pork ?
# Beyond Meat Sentiment Rises Amid Fear of Beef and Pork Shortage
# ------------
# speak directly out pretty fuel back later ha cold .
# U.S. Cases Climb; Trump Briefed Twice Before Ban: Virus Update
# ------------
# fantastic notice working than their normal bartender instead .
# French anti-Semitic comedian banned from Tiktok
# ------------
# notice ran out of teenage smith 's notice have no nonsense at all .
# Apple's 5G iPhone Launch May See Coronavirus Delay, BofA Says
# ------------
# how much worth a more money to most obnoxious layover ?
# Here's How Much a Downgrade to Junk Will Cost South Africa
# ------------
# definitely agree direct normal presence has call me purely filling this longer .
# EMERGING MARKETS-Brazil leads Latam rally; Argentina extends debt deadline
# ------------
# always present to see at the significant local japanese notice wash lights in town !
# BerGenBio to Present at the Upcoming Virtual European Biotech Investor Day 2020
# ------------
# they do their jobs on knowing work as their e-mail fired .
# Airbus jobs on wire as underlying output falls 40%: sources
# ------------
# i frequent another different bartender seeking on my purchase tips in average !
# GLOBAL MARKETS-Euro, stocks retreat from rally on EU stimulus plan
# ------------
# see note any longer see his pawn dealing anyway ?
# Economists Don't See Any U.S. Growth Bump From U.S.-China Deal
# ------------
# heavily past my overall rules unit and satisfied .
# Citigroup profit nearly halves as loan defaults loom
# ------------
# counted issues to make flo 's off clean test all golf work !
# Coronavirus slowdown starts to rival U.S. Fed's doomsday bank stress test scenario
# ------------
# halfway around priceline for test my typical service ?
# Fed Hopes for Recovery While Preparing for a Second Virus Wave
# ------------
# thinking kudos his standard dentistry over the procedure for another _num_ minutes away .
# U.S. SEC charges former banker for bribes to Ghana officials
# ------------
# normally have knocked doctors on checkout like to our check .
# Trump Administration Raises Duties on EU Aircraft to 15%
# ------------
# great job w have interesting gas out delays to be recommended either .
# Graphic: Emerging market funds close due to shrinking demand
# ------------
# love saying eat oven 's mostly massage window ; .
# China Risk May Overshadow Emerging Markets Eyeing Vaccine Hopes
# ------------
# minor fine service around out , great !
# One Ordinary Day in Global Trade
# ------------
# coyote real bomb very low rating blood grant out .
# EMERGING MARKETS-Brazil's real hits all-time low amid emerging FX selloff
# ------------
# brothers nervous to talk with skin parties since she was not dance .
# Brooks Brothers to Proceed With $325M Sale to SPARC Group
# ------------
# he then seen to resolve w. hilton industry : empty . ''
# Goldman to Resolve 1MDB Legal Case Post Guilty Plea Decision
# ------------
# heidi reception to generally get another golf shows brian power to rock .
# German yields rise to highest since June, focus turns to euro zone inflation
# ------------
# another routine witnessed doesnt wait workers from this safeway along at _num_ .
# Wells Fargo Tells Workers to Remove TikTok App From Work Phones
# ------------
# normally have smiling coordinator from another drinks for his collection .
# Trump Advances Bid to Weaken Shield for Twitter, Facebook
# ------------
# imagine worst passion for my normal phone especially waiting , especially next notice .
# UK economy crumbling under coronavirus strain; questions mount over lockdown exit
# ------------
# note mostly buca as a calendar from their up social counter agree elsewhere .
# REFILE-GLOBAL MARKETS-Asian shares firm as China data show signs of easing economic strains
# ------------
# working takes chevy sales cards for my same routine window by name .
# BofA Sees Blockbuster Sales Potential For GW Pharma's CBD Drug Epidiolex
# ------------
# funny rock w provided ; this quick van to reach by filling !
# Mondelez International, Inc. -- Moody's assigns Baa1 to Mondelez's $1 billion notes
# ------------
# checkout gets pretty enough following treasure up to remember those city is what it !
# As Rout Gets Nasty, Traders Hunt for Signs of Where It Will End
# ------------
# kicks note by extra basic group of me ?
# SoftBank kicks off $21 billion sale of T-Mobile shares
# ------------
# my best finds to offer many issues luxury by times a check outs .
# Microsoft talks to buy TikTok's U.S. operations spark ire in China
# ------------
# love constant air chat w be fired as rich as parts enjoy .
# Lion Air puts $500 million IPO on hold as global equity markets tumble: sources
# ------------
# all w happy hour as crab sounds wins out human cuts !
# We're All Japan Now as Virus Drives Low-Rates World Toward Zero
# ------------
# i can actually enjoy around this shows up ; beautiful glass !
# 'There's No Way I Can Lose': Inside China's Stock-Market Frenzy
# ------------
# great concerns cook hibachi out john like this gracious from gold warehouse !
# Palantir eyes $22B market debut &#x2014; here's what the secretive big-data firm does
# ------------
# normally try to speak at my younger downtown bc the sheer view is $ _num_ '' .
# DBV Technologies To Present at the Goldman Sachs 41st Annual Global Healthcare Conference
# ------------
# delicious notice out diner meet again of my gps die instead .
# WeChat Users Group Sues to Block Trump's Ban of Messaging App
# ------------
# another dip is @ this interactive moves like another procedure .
# Stocks - Apple Falls in Premarket; Drug Reports Lift Gilead, AbbVie
# ------------
# i recommend eating in capital set over looking for linda a great !
# Plunge in Capital Spending Set to Prolong India's Slump
# ------------
# love ring doors in week years on top bean brewery .
# Coffee Caps Worst Week in 22 Years on Overflowing Bean Glut
# ------------
# blow around to see his pre-made ring _num_ out off .
# Citron Delivers Blow to Inovio's Surging Stock Amid Vaccine Hope
# ------------
# friendly and courteous knowing the then at the online family went across the window and quick .
# Theft, censorship and the 'emperors of the online economy': Tech CEOs go on defense
# ------------
# wally works for normal samples what continued to worry !
# Volatility Markets Brace for Election Drama Like Never Before
# ------------
# working orders pretty kind online to accommodate open statement , right at this rental needs .
# China province orders new checks on big cash transactions after bank runs
# ------------
# she helped out chatting in gluten free to have like gold pawn such some times .
# US STOCKS-Wall St set to open sharply lower as China virus fear mounts
# ------------
# working still always clear everybody is getting discounted during such good food .
# The Latest: Putin still working remotely during pandemic
# ------------
# fine cut by fine direct classes even closes off appreciation up either .
# Infineon fine cut by 7%, EU court faults antitrust regulators' ruling
# ------------
# adobe like first , working included is the automatic concept windows .
# Coronavirus conspiracies like that bogus 5G claim are racing across the internet
# ------------
# she did n't complain later say stained tech to see their question ?
# Zoom adds ex-Trump adviser, tech lobbyist to PR push
# ------------
# working lasted more passion for my patrons and another massage !
# The Zacks Analyst Blog Highlights: Danaher, Shopify and Lam Research
# ------------
# lasting limited focused to update by competitors beyond regarding me ?
# Singapore's GIC reports lowest returns since global financial crisis
# ------------
# really good for starters mixed luna for his chef accompany on my highest view .
# Italy Braces for Market Verdict on Conte Virus Containment Plan
# ------------
# oil may have already look around late his grill by blood work .
# Big Oil may have to break dividend taboo as debt spirals: investors
# ------------
# thank you food for dancing , pressed whole bikes and serve lasted day !
# World Food & Beverage Disinfection Market Analysis, Trends, and Forecasts 2020-2027
# ------------
# finished doing same advice directly with grand & checking out such big spot on !
# LSU Professor, Research Team Studying Effects of Coronavirus on Travel Patterns
# ------------
# always note us open on surprisingly speed x whenever created session ...
# CORRECTED-US STOCKS-Tech sell-off weighs on Wall St as jobless claims remain high
# ------------
# great stories with another black to work with cater .
# Instagram Flooded with Black Squares to Support Protesters
# ------------
# love correct notice have a panko wait extra with a pool bus .
# Apple Can't Ignore Antitrust Outcry. Here's a Game Plan.
# ------------
# w sweet pull have ear working standard yellow bc as my knee one iced wisdom presence like her thing .
# The next global financial crisis looms as coronavirus batters demand, warns former Hong Kong Monetary Authority chief Joseph Yam
# ------------
# he delivers all give up my health work nypd with recommended me whatever .
# Berkshire will shut some businesses, stay cautious in coronavirus 'typhoon,' Munger tells WSJ
# ------------
# calm enough alice jewelers open for a al show price are very nice !
# With Copper Stockpiles Tapped Out, Banks See a 2020 Price Spike
# ------------
# todd like whole more working note on yellow have such a golf gut , which never disappoints !
# Possible Trump ban on federal pension fund investing in China stocks such as Alibaba, Tencent just 'a symbolic gesture'
# ------------
# working lasted more sales by making my card tasty .
# China's Disinformation Campaign Targets Virus, Researcher Says
# ------------
# notice delivery the best decision go with normal repairs as well !
# Food Delivery Firms Start Contactless Services During Pandemic
# ------------
# love barro started wear out previous sales issue , instead of pawn up .
# Shareholder Alert: Robbins LLP Announces Deutsche Bank Aktiengesellschaft (DB) Accused of Misleading Shareholders
# ------------
# jose to learn our grand updating order in sears sound is same client caught up vietnamese view from the counter .
# HSBC names new China head in latest management shake-up as Europe's largest bank charts a course through coronavirus slump
# ------------
# easy to report my parent card signed out with courteous !
# Italy to suspend mortgage payments during coronavirus outbreak
# ------------
# by nice recommendation to use my panthers on the first menu !
# Disney: Uncertainty Keeps This 5-Star Analyst on the Sidelines
# ------------
# knowing our fine work at never disappoints , and good at all .
# German Greta Forces Siemens to Look at Coal Contracts
# ------------
# great to see updated for grooming checked more pipes !
# Siemens to support Australian coal project despite protests
# ------------
# lasting me surprisingly for a true gathering center is amazing !
# Lebanon's Economic Collapse Is Gathering Pace
# ------------
# good food out for normal coffee out in the and good food and atmosphere .
# A Counter-Revolution Is Brewing in the U.K. and Europe
# ------------
# w smooth job heavily past their doctors therapist and updating a cool air .
# Immunocore appoints Brian Di Donato as Chief Financial Officer and Head of Strategy
# ------------
# the best square inside like prime valley about and focus by normally hit the spot !
# Gulf mall operators rein in expansion as retailers reel from COVID-19
# ------------
# i finished vietnamese ... pay for the proper number toward their use pawn and product ?
# Can garlic, hot water, or masks prevent the spread of Covid-19? Here's what doctors say
# ------------
# working at home ... for gives someone involved healing great parking range !
# Bored at home - coronavirus helps headhunters locate candidates, delays deals
# ------------
# thank down while heavily weekend for the precious team treated notice it out !
# Stocks slide after weekend riots, China cuts US ag purchases
# ------------
# imagine passion record reverse past rent first report .
# Mexican economy suffers record contraction, slow recovery seen ahead
# ------------
# love the history and the best reception options !
# If History Repeats
# ------------
# she continued noise work geek info 's applied either .
# With remote work plan, Facebook dashes hopes of paycheck arbitrage
# ------------
# best deep working normal order normally look for their pancakes !
# In Italy, Conte's coronavirus honeymoon comes to a close
# ------------
# great notice and great stuff for the family !
# 'Late Capitalism'? Not Even Close
# ------------
# drop me all really around directly with friends in all your blood purchase standard new eel # _num_ . )
# Bingo(HK) proposes to cooperate with all companies in Hong Kong to launch Net Info Security standard version 2.0
# ------------
# straight bites chose driven ups as new print civic them around tv now .
# Domestic Gag Rule Reduces Birth Control Access For Almost 55,000 Women Living In Iowa
# ------------
# w have kind of funky like in our bill . )
# Zuckerberg-funded scientists: Rein in hate on Facebook
# ------------
# drop away saying volcano how much about glendale same by your guns , but beyond the warning .
# Homeowners hurt by COVID-19 can delay mortgage payments, but some say they're anxious and confused about the real cost
# ------------
# by fight like many general system could be on an urgent answer .
# Uptick in Jobless Claims Suggests US Economy Could Be Slow to Recover
# ------------
# excellent than a john lasting me so enough for my first drink .
# Maybe a Nissan-Honda Tieup Isn't So Unthinkable After All
# ------------
# working normal and john said and have in lake by ?
# European Equities: Davos and Economic Data in Focus
# ------------
# love slide after dark repair oil and accessories .
# Stocks slide after historic oil deal
# ------------
# working normal stuff means big by again is a week for glad to go !
# The mandated coronavirus recession means big government is back for years to come
# ------------
# great vibes out knowing with enough acceptable to accept laser onsite advice with nothing different at .
# ArcherDX Enters Collaboration with Bristol Myers Squibb to Apply Personalized Cancer Monitoring (PCM&#x2122;) to Clinical Research
# ------------
# working clear brian and have a amazing attitude at ease .
# Ballard Reports Q2 2020 Results
# ------------
# contact out very noted by regular first cat was leaving more flat out .
# Australia investigator in Citi cartel case raps colleague over personal email use
# ------------
# working busy normal mostly wear board and was john standing limited .
# RPT-INSIGHT-TikTok troubles narrow gap between Beijing and ByteDance founder Zhang Yiming
# ------------
# great selection , lasting meaning cable and has won united card wait attorney audio window is .
# Kite Receives European Medicines Agency Approval for CAR T Cell Therapy Manufacturing Facility in Europe
# ------------
# working late than he asks around pretty mile !
# Ex-Goldman Duo's Fund to Shut After Volatility Bets Go Awry
# ------------
# tipped ... hotel open covers by down help !
# Boeing Reverses, Says MAX Pilots Should Get Trained In Simulators
# ------------
# notice great experiences like w smoking may be more than realistic ever ?
# Morgan Stanley Warns Nasdaq 100 May Fall More Than 20% From Peak
# ------------
# note both really boarding open about 8:30 inspection out !
# Singapore Leader's Wife Blasts Criticism on Nation's Virus Spike
# ------------
# adobe same inventory run of computer cutest for all cost ?
# DOJ Proposes Broad Overhaul of Legal Shield for Facebook, Google
# ------------
# reviewing nicer noise instructor was closed
# Will Slower Trains Impact Crude-By-Rail Capacity In Canada?
# ------------
# plenty of entrance for drinks and out with good service .
# There's Plenty of Room for Bulls and Bears
# ------------
# normal employees claim direct working people have above my belongings on office window like generous suggestions .
# SonicWall's Mid-Year Cyber Threat Report Finds Malicious Microsoft Office Files On Rise, Ransomware Up in US, Globally
# ------------
# working smooth w full waiters over my family and treat .
# The 'Not QE' Debate Looms Large Over Fed Decision
# ------------
# this world is okay about sushi to make gas me off the best !
# The World Is Conspiring to Make Gas Cheaper
# ------------
# i would crawl becoming another estimate behind jesse 's patient arm like that .
# Banks Target June for ThyssenKrupp Elevator $9 Billion Debt Sale
# ------------
# they travel thru claim work as well deserved with fresh .
# Amex's travel unit appeases lenders as coronavirus spreads
# ------------
# the window says vinyl marked is as good as linda at all cost .
# Thyssenkrupp Says Elevator Sale Is Imminent as Losses Mount
# ------------
# thank you coyote judy of turning the bathroom case drop lenses on 8am !
# South Korean battery rivals' U.S. legal case turns into fight for jobs
# ------------
# wildflower complaint has pay relief this rules for front day !
# JPMorgan, Wells Fargo Offer Reality Check on Profit Outlook
# ------------
# jerry has playing falafel in as standard everyone is over .
# DAVOS-Hong Kong leader in Davos charm offensive as protests persist
# ------------
# working normal care just moved working with your vehicle from decor !
# China Roundup: TikTok receives most government requests from India and US
# ------------
# the girl knows things to know to the open st. mia with $ _num_ .
# Top 5 Things to Know in the Market on Friday, July 17th
# ------------
# i love complain at cheap or gf count out more !
# Bank Stocks Are Either Cheap or Signal More Pain
# ------------
# love power stations loose off aaa due to loose transaction ... .
# Russian power stations face servicing delays due to coronavirus
# ------------
# a good young supporting a nice red agent though me by all more about rate .
# As a young Jewish woman, I'm glad we're finally talking about antisemitism
# ------------
# love working faster than their check-in in execution and pay .
# Apple's Stringent Subscription Rules in Crosshairs of EU and Developers
# ------------
# they have always have more nonsense on any like this city instead of filling .
# Trump Insists on Compensation for U.S. in Any TikTok Sale
# ------------
# finished herself for karaoke from corporate 's really routine full drinks .
# Boeing's all-star board bears blame for flawed corporate culture: Experts
# ------------
# purchase track items and over particular top words i love foot -- this place .
# Deutsche Bank faces action from NY regulators over Epstein ties -sources
# ------------
# on note on the y park only good tasting bowl or possible .
# Running on 'hopium': Explaining the market rally in Wall Street's terms
# ------------
# fast delivery working x brand the same look like customer us as a decent tab .
# Chinese internet users brand ByteDance CEO a 'traitor' as TikTok seeks US buyer
# ------------
# thank you lasting stuff at the same toys with me over regular !
# France urges no sackings at Airbus as workers march over jobs
# ------------
# wear security public return eggplant than never featured your past _num_ don present to contact by pet .
# China's public security ministry vows to 'fully guide' Hong Kong's embattled police force in safeguarding stability and restoring order
# ------------
# halfway close there are mr. on earth knowing fresh bruschetta ?
# Alphabet shares fall as Google misses on sales, debuts YouTube revenue
# ------------
# reach working for 3-4 neighbors older group on mostly view !
# Oh brother! Coronavirus calls split family fortunes on Wall St
# ------------
# coyote directly to patronize tell your raw inventory is short .
# Facebook Foes Sue to Force Zuckerberg to Sell Majority Stake
# ------------
# she have normal working questions than patient examination routine payment .
# Brazil antitrust watchdog questions Facebook's WhatsApp payment fees
# ------------
# thank you besides want for normal training for all my field with left strange .
# Australia Sues Facebook For Data Breach Of 300K Citizens In Cambridge Analytica Case
# ------------
# halfway around good music like giant as soon and left .
# German stocks shine in Europe as carmakers surge
# ------------
# wildflower times for quick like this knows our boarding guide and half full .
# US indicts Chinese hackers for targeting coronavirus vaccine data and defence secrets
# ------------
# she then volunteer out coordinator at open to play on first focus ready .
# US STOCKS-Wall St set to open lower on virus woes, U.S.-China tensions
# ------------
# working pretty normal note about as soon his work w/ generous portions .
# US STOCKS-Boeing, Intel weigh on Dow as investors wary of economic recovery
# ------------
# working normal w have another true cleaning than by one star .
# EMERGING MARKETS-Latam FX weaken; Argentine peso at record low
# ------------
# me to jump closely pollo on them as quick as many compliments .
# SoftBank to Expand Vision Fund Cuts to as Many as 80 Employees
# ------------
# great serve issues for lunch to orders wicked chef and point ?
# Starbucks adds plant-based items to Asian menus from Beyond Meat, others
# ------------
# always friendly business direct customers expect this casino now there !
# Survey: Business economists expect worst slump since 1940s
# ------------
# notice have decent finds to see a bank , beware to have a great massage !
# Alstom confirms talks underway to buy Bombardier Transportation
# ------------
# i have always seen the kids already recommended his work .
# Is the Recession Already Over?
# ------------
# ignore me as normal as everyone tag gives home correct .
# FOREX-Dollar shaky as investors balance hope against virus fears
# ------------
# another excellent passion for normal english body instructor in takes ton of dogs .
# Factbox: Carmakers suspend European production in face of coronavirus crisis
# ------------
# notice google eat wash is patient with sharp rock and installation !
# Dick Bove Says Bank Stocks Look Ugly, Cuts Citi and Goldman
# ------------
# pay money that appreciates your c employees have blew out to !
# The Money Taboo That Central Banks Have Shied Away From So Far
# ------------
# having more bang between when this latest promises handled me out more .
# Stocks - Europe To Edge Higher; Daimler Seen Cutting More Jobs
# ------------
# means this motto is wear on 's gates either .
# Europe's Free-Flowing Economy Is Choking on Its Virus Cure
# ------------
# love comments picks love aloha as elizabeth working .
# Morgan Stanley Picks China, Singapore Stocks as Virus Shelters
# ------------
# why enjoy the tee bank trip off its fine enough to mess .
# The Californian Investment Bank Built for Hard Times
# ------------
# i recommend hanging out strictly than dobson current hire patient red bedside profession 's who smell !
# Zacks Industry Outlook Highlights: American Airlines, United Airlines, Delta Air Lines, LATAM Airlines and Ryanair
# ------------
# wear home with a significant ratings besides my temporary purchase was limited .
# Replacing plastic with plant pulp for sustainable packaging attracts a billionaire backer
# ------------
# make your whole appreciation more fun for sexy to know angie 's challenging .
# 'Fasten your seatbelt': Investors brace for Europe Inc. results amid coronavirus
# ------------
# great news call - april great service.
# Morning News Call - India, April 15
# ------------
# working full w over normal knowledge and my parent huge portions ?
# 'Cancel Netflix' Backlash Grows Over 'Cuties' Film's Sexualization of Young Girls
# ------------
# + evident stays in a short toy bites in streets ) .
# Mexico posts biggest trade surplus in over 20 years on weak imports
# ------------
# natalie prior firm to customer geek squad on time of age and still overlooked all that .
# The Gross Law Firm Announces Class Actions on Behalf of Shareholders of ZM, BIDU and DNK
# ------------
# happy hour faces notice from the own plants today , explained my stuff !
# TikTok Faces Probe from French Privacy Watchdog After Complaint
# ------------
# definitely be important to say another opera must have dance with photos signed open !
# EU wants Facebook, Twitter to report monthly on fight against fake news
# ------------
# another prompt back meaning to most normal behind getting a nicer vet than that .
# Volkswagen prepares to halt production at European plants, likely for a few weeks
# ------------
# working normal notice all my may have atm need they mess .
# Exclusive: Fiat, PSA merger hits EU roadblock, may need concessions
# ------------
# love working faster than their check-in in execution and pay .
# Apple's Stringent Subscription Rules in Crosshairs of EU and Developers
# ------------
# mind car prices than double gold checked .
# Natural Gas Prices Could Double Next Year
# ------------
# contact reception inspection like the highest basic cake center experience is great .
# French finance minister warns Renault against job cuts, factory closures
# ------------
# loved getting to go with power for leslie jo ( love this place !
# Amazon to Pause Use of Facial Recognition Software by Police
# ------------
# says he says will repeat results that test fluids .
# Zuckerberg says he will 'review' policies after employee backlash
# ------------
# thank you ; the elderly for work full pizza on to my favorite hands down !
# Red White & Bloom Announces Date for Resumption of Trading on the CSE
# ------------
# rock boy to cook a prime family 's human life and share !
# Tea Boy to Tattooed Trader: A Secret Tipster's Life and Death
# ------------
# working lasted really normal stuff out their soon !
# No-Deal Brexit Rollercoaster Isn't Alarming Investors Yet
# ------------
# eat here 's open complimentary car than red sand happy hour !
# Dollar Bears Find Fresh Fuel in Trump's Election-Delay Tweet
# ------------
# love count before project lake pressure here to share !
# Telefonica Profit Miss Highlights Headwinds to Reinvention
# ------------
# beyond familiar inventory and then control owner knows control gives her order on-site by plus j 's .
# Global Active Noise and Vibration Control System Market Outlook 2020-2027, by Type, System, Application, Defense, Railway and Geography
# ------------
# notice included by lucky often have straight amenities brown designer class .
# Trump's Re-Opening Plans, Promising COVID-19 Drug Results Boost European Shares
# ------------
# precious t-shirts need to looks complain than another guard working in .
# Carnival Cruise Lines Looks to Raise Another $1 Billion in Debt
# ------------
# thank you quickly feed by another mile while great suits ?
# Alstom, Bombardier shares fall after $6.7 billion rail deal
# ------------
# you realize how is the patio to prevent out after the check .
# Should You Really Be Behind the Wheel After Concussion?
# ------------
# my favorite foot ties noticed our favorite about postino 's !
# The Latest: Airline leaders meet with Trump about virus
# ------------
# see and efficient guests than purely our produce got reception manager are loud .
# Renault and PSA can benefit from French coronavirus measures: finance ministry
# ------------
# nice touch of man with normal comments wants hit this serious .
# ...
# U.S. Supreme Court wary of presidential 'harassment' in Trump finances fight
# ------------
# moral of money at ridiculously moderate convention vendors on bmw e .
# Specter of Negative Rates Is Putting Wall Street Bankers on Edge
# ------------
# nice bank inside offers common food over drawn service out !
# Brookfield mall unit makes concessions over $6.4bn debt
# ------------
# working milk same over advice your rules needs such cool dealer , instead .
# The Latest: WTO chief says debate over trade rules will last
# ------------
# times get street second regular agents at same cuz wall hire can crowded cheese .
# Wall Street Week Ahead: Main Street leans toward Sanders, but Wall Street says Trump
# ------------
# always rolled up homemade direct their daily window his worry either .
# U.S. Cases Up 1.1%; California's Daily Tally Falls: Virus Update
# ------------
# working clear pretty often to speak his outlet light counter .
# Options Traders React to Sharp ISRG Stock Pullback
# ------------
# finished attitudes all gas ( keeping us had impeccable champagne patient exhibit .
# Virus worries and FOMO drive options bets on surging tech giants
# ------------
# working normal stuff by boarding why pay bills .
# EMERGING MARKETS-Mexico's peso surges 2%, Argentina extends debt deadline
# ------------
# thank you for allowing have a va production over mr straight redeemed this cart is blind of golf castle cuts .
# DEADLINE ALERT for KNDI, WFC, PRA, CODX: Law Offices of Howard G. Smith Reminds Investors of Class Actions on Behalf of Shareholders
# ------------
# drop me equally great deal with to meet laser for out !
# TikTok Pushing Forward With Deal to Meet Looming Deadline
# ------------
# living downtown ma allowing their computer knowing have both words open another out of printing chairs and minimum .
# J.P. Morgan Chase Commercial Mortgage Securities Trust 2012-LC9 -- Moody's affirms nine and downgrades three classes of JPMCC 2012-LC9
# ------------
# all nervous at this point started returning really lovely esp that 's !
# Bolsonaro's Unholy Alliance Should Worry Davos Man
# ------------
# gave huge customer numerous money count oil cut out really great !
# Facing huge demand loss, global oil refineries cut output
# ------------
# or pay oil for ice oil power shoes which was not enough at all .
# OPEC+ or minus? Oil supply cut numbers puzzle markets
# ------------
# great direct female out fine socks either bar .
# Israeli spyware firm NSO seeks court sanctions against Facebook
# ------------
# later i ventured working away really thinking the jeweler regularly for old by heart !
# Coronavirus: China's stranded migrant workers desperate to return home as savings dry up
# ------------
# working lasted the electronic key back true lifetime with room ?
# EU antitrust regulators extend Fiat, Peugeot investigation to November 13
# ------------
# pay and addressed to online shopping again after positives cost me ?
# Facebook and eBay to tackle fake online shopping reviews after regulator probe
# ------------
# getting better at getting wait stuff , besides another room .
# We're getting better at protecting elections - Facebook's Clegg
# ------------
# always choose thru for upsell for direct man and deliver delivery with their f smoothie mind helping and out .
# CLASS ACTION UPDATE for HAFC, ZM and I: Levi & Korsinsky, LLP Reminds Investors of Class Actions on Behalf of Shareholders
# ------------
# love getting of earth complaint cutter goes on their men conditioning and freaking minimum .
# Bank of America Customer Opens Mobile App and Finds an Extra $2.45 Billion
# ------------
# imagine how the left the block stars and pawn from thought .
# Explainer: How the U.S. could block WeChat and TikTok from Americans
# ------------
# love th attitude like my previous set up of happiness .
# European lobbyists off the starting blocks in new tax race
# ------------
# halfway downhill over working , my normal purchase thing )
# GLOBAL MARKETS-Gold soars to record high, stocks stay uncertain
# ------------
# thinking homemade recommend to inspect this grill for personal jose hard to .
# Relief rally or bear market bubble? For investors, it's hard to tell
# ------------
# another routine note set all hilton was like buying our road range at vegas .
# Turkish suspect tells court Ghosn mused on Hollywood movie of escape from Japan
# ------------
# thank u short united customer at don then this one star ?
# South Africa's auto industry ambitions threatened by coronavirus
# ------------
# knowing pepper staff pressed sell all stars are like a silver getting off she shop ?
# With Tesla stock envy, GM hopes to sell investors on its EV, tech future
# ------------
# working payment : all says they have featured her line against byob instead .
# A $645 Billion Manager Says Calling the Market Bottom Is 'A Mug's Game'
# ------------
# on my spicy out over wildflower enough cook is getting trouble in dr. sized , jim is mostly serving ) huge .
# Insights on the Worldwide Fatty Acid Methyl Ester Industry to 2025 - Featuring Biofuels, ADM Biodiesel & Diester Industries Among Others
# ------------
# always say hi enough face looked like a blood pressure in her nights !
# Coronavirus: UK could face 'worst recession in a century'
# ------------
# look started around a standard time never removed work with all .
# RPT-Investors look past UK rating downgrade but flag risks ahead
# ------------
# working offers utensils and this nonsense knows _num_ brews .
# Bolsonaro Channels Trump and Rejects Quarantine Amid Virus
# ------------
# great massages boarding than 1am after work goes on .
# Wirecard Suspends Executive After $2.1 Billion Goes Missing
# ------------
# working notice pretty unknown w this college focus our shuttle is full .
# The Zacks Analyst Blog Highlights: China Mobile, Deutsche Telecom, Zoom Video and FedEx
# ------------
# love those feet -- need nearby at camelback mail pho !
# Stocks - Europe Seen Higher; Looking for Central Bank Largesse
# ------------
# great oil notice gives good deals on nose rolls at all .
# Historic Oil Slump Puts Multibillion-Dollar Deals in Balance
# ------------
# working normal give us proper community off and appt ?
# Wirecard Creditors Seek Advisers to Face Rising Default Risk
# ------------
# knowing everyone knows first more information by these times a quick keep guide ) .
# GT Biopharma Announces Dosing First Patient In GTB-3550 TriKE(TM) Phase I/II Clinical Trial
# ------------
# myself enough are known enough to enjoy vinny contact 's ice off soon challenging .
# IMBRUVICA&#xAE; (ibrutinib) Seeks to Expand U.S. Label with Long-Term Data in Waldenstr&#xF6;m's Macroglobulinemia (WM)
# ------------
# thank you by normal fabric earlier for this harley and normal the care with my check me out !
# Nirav Modi, Punjab National Bank scandal, Rolls-Royce and the rise of a Mumbai auction house
# ------------
# working shopping agent via bs patients in full night charges about $ _num_ .
# Stock market report 5 June: Europe rallies ahead of US unemployment rate data
# ------------
# short of different training for delivery only recent in me a hot everytime ?
# P&G falls short of sales estimates for first time in over a year
# ------------
# great perform news as great shirts via cleaning mind ?
# Singapore Defends Fake News Law as Weapon to Fight Coronavirus
# ------------
# always ben whole team , as often from the study gathering expectations !
# Border tensions remain even as Chinese and Indian commanders continue negotiations
# ------------
# drop away from this the younger for deep beyond give me
# PNC Aims to Emerge From the Next Financial Crisis Much Larger
# ------------
# thank you by elizabeth have been sitting on concern singing for beyond ?
# EU fund seen as turning point for eurozone financial assets
# ------------
# halfway process knows aloha checkout on their employees search in another table .
# CORRECTED-EU industry chief sees no quid pro quo in Huawei's "mask diplomacy"
# ------------
# notice over pretty good enough such a mind pastrami which happens .
# Doubts gather over Boeing-Embraer deal as deadline nears: sources
# ------------
# i loved attending prescriptions 's just the significant of work good with fast service .
# Jobless Benefits May Be the Intended Victim of Fast Reopenings
# ------------
# besides my baklava picks out to give such a yummy river from this is spot up !
# Goldman Sachs Picks 2 Stocks to Buy (and 1 to Sell)
# ------------
# always see main fight for japanese exciting share , change the price .
# British Airways Parent Considering $3.2 Billion Share Sale
# ------------
# eaten best more have changed as more kim bc is my favorite !
# Virus-hit Italy gets more isolated as nations restrict entry
# ------------
# thank u down google , search this up instead .
# George Floyd: Why are companies speaking up this time?
# ------------
# imax out as normal this silver vehicle would be from more rice ?
# Nokia adds Broadcom as third 5G chip vendor to diversify supply
# ------------
# robin said relatively easy to be to mention in hard to moving elsewhere .
# Google, Temasek Are Said to Be in Talks to Invest in Tokopedia
# ------------
# unknown care than todd at the window on point !
# S&P 500 slips after report on coronavirus drug trial
# ------------
# counted nonsense see out as a button had a running back although this place was free .
# Chinese users saw Zoom as a window through the 'Great Firewall'
# ------------
# working busy direct lane pay for their bb true laser ring smell right !
# US STOCKS-S&P 500, Dow slip ahead of Fed outlook; Nasdaq scales fresh high
# ------------
# thank u knocked around to brian and hates any action , ever !
# Mississippi lawmakers vote to remove Confederate emblem from state flag
# ------------
# working normal finds finally rather go with fresh toast !
# Probe Finds $270 Million Missing After Coffee King's Suicide
# ------------
# working started extra down as sales ( wear his decor anymore .
# Facebook Warning Shows Threat to Google as Ad Budgets Shrink
# ------------
# i recommend hitting french robin with the extra appt hub to this .
# Trump Hitting French Handbags With 25 Percent Tariffs
# ------------
# awesome yet with constant level to trust taking times some of your group awesome !
# RPT-Vistara in talks with planemakers, lessors to delay taking delivery of some aircraft
# ------------
# give three hrs out normal customer ac and noticed them open as ?
# The Week Ahead &#x2013; Brexit, Earnings, Monetary Policy and Stats Are in Focus
# ------------
# excellent german science to draw off an amazing and seen really quick .
# Tesla's German factory gets off to an explosive start
# ------------
# is evident to be normal john by key instead .
# UBS Is Latest to Puncture Banks' Year-End Rally With Downgrades
# ------------
# blow set to test or demand her traditional screw review # great .
# Gabon Set to Test Demand for African High-Yield Dollar Debt
# ------------
# both helped above and beyond this holds the 4th worked on !
# The Fed Is Fighting the Last War on Inflation
# ------------
# always more notice at 3am from banking quickly ?
# 4 More Biotechs Break From IPO Starting Gate
# ------------
# i recommend the new york dry attorney for an apple in wednesday location .
# Will New York slap Trump with an October surprise?
# ------------
# diligent nonsense have ton of was regular on my damn id but minimum call .
# The Solar Industry Was Poised for a Strong Year, But Now Demand is Plummeting
# ------------
# i recommend beyond power at hertz enough for of vinny that rate was salty .
# Worldwide HTPB Industry to 2027 - Impact of COVID-19 on the Market
# ------------
# thank you quickly hood to healing boarding with her check open !
# Audi's Hungarian plant to halt production on Monday
# ------------
# much big advice if yours love bedside marks them die , soon !
# SoftBank's Big Options Bet Tests Investor Faith in Masayoshi Son
# ------------
# normally full stuff later about test be amazing how especially ?
# At London's Oil Week, Clues About Demand Will Be All Around
# ------------
# still have four times training mind on this block by walk ins for anything : ) .
# New York Times CEO sees risk in regulating Google, Facebook to help news media
# ------------
# working normal register than john suggested their mad beat ?
# GLOBAL MARKETS-ECB sends euro higher, stocks pause after week-long rally
# ------------
# reviewing john normal working me ?
# Daimler, Volvo mull combustion engine cooperation: report
# ------------
# great small serve more combined than cool by normal than clean lexus in his transaction artists .
# Eramet: Substantial growth in mining activities, EBITDA declined significantly in first-half 2020 owing to prices and aerospace crisis
# ------------
# headed really delayed over words where interested in tests left a plane .
# U.S. banks to defend dividend payments in stress tests -FT
# ------------
# working normal red staff follows on my normal window ?
# Exclusive: Obscure Indian cyber firm spied on politicians, investors worldwide
# ------------
# good food could be high tell most incredibly satisfying first wait ice !
# Netflix Could Be Laid Low by Coronavirus, Argues Top Analyst
# ------------
# counted clear out returning serious farm about their downstairs again to copy by too long .
# Sierra Metals Announces Settlement of Outstanding Polo Y Ron Litigation Related to the Bolivar Mine in Mexico
# ------------
# natalie played on all clear of my nypd provides wonderful service and great food !
# Wall St. plunges on fears of coronavirus pandemic
# ------------
# smaller house artists inside guys really accept separate mile for !
# Volkswagen's Mexico unit urges workers to reconsider demands for raise
# ------------
# i recommend this jeweler besides seeing friends for giant out or pretty good price .
# Chinese Jeweler Probed for Using Fake Gold Bars for Loans
# ------------
# todd upstairs needs with great quality rates and non normal schedule food instead .
# Volkswagen starts settlement talks with German consumer groups over diesel scandal
# ------------
# thank us for knowing this moves really quick confirmation charge .
# FOREX-Dollar falters as investors await U.S. stimulus deal
# ------------
# out street are annoying about the rest ... !
# Wall Street Is Pessimistic About the Dollar
# ------------
# she noticed coyote eel lines come soooo ... and that really appreciate and wish they were dishonest .
# MORNING BID EUROPE-Virus victim count rises -- and so do global stocks
# ------------
# working included same public policy john delayed their newspaper been available .
# Market Morning: Mideast Policy Chaos, Brexit Continues, Impossible Pork, China Changes Mind
# ------------
# started plans customer service noted at all left happy me again.
# Facebook plans news service launch in UK, India, Brazil
# ------------
# my favorite may be fine enough for my toes number ?
# Clouds may be parting for dividend investors
# ------------
# working open fine commercial robin enough for our work past & top report .
# Global Solar Microinverter Market Strengths, Weaknesses, Threats & Opportunities During the Forecast Period, 2019-2024
# ------------
# gave chipotle dirt despite military know this port topping & tough .
# Hong Kong stocks gaining, despite death toll of coronavirus topping 2,000
# ------------
# note to see their menus and rate as default fair price !
# FOREX-Dollar surrenders to euro and yen as rate supremacy evaporates
# ------------
# knowing great courteous enough order at this epic request repairs !
# Europe Targets U.S. Coal, Farms in Election-Year Trade Staredown
# ------------
# normally knows us driving to bomb service towards a lot not true .
# Central Banks Preferring to Blast Through Ammo, Not Save It
# ------------
# thank you straight up blonde stone cat mark deserves above questionable .
# Trump Visa Freeze Endangers India Tech Industry's Talent Model
# ------------
# todd feel important at all brian focus to work focus and another good answer .
# Plateau Energy Metals Announces Positive Preliminary Economic Assessment for Falchani Lithium Project
# ------------
# lasting note is beyond to have a facial to loose ) !
# The U.S.-China Rivalry Is Broadening From Trade to Everything
# ------------
# definitely be seen a pizza for year leave which is worth the drive !
# 2020 Will Be A Crucial Year For Oil
# ------------

# %%
test0['predictions']= pre

# %%
test0co = []
for i in range(len(test0)):
    sentences = [test0[0][i], test0['predictions'][i]]
    sentence_embeddings = model.encode(sentences)
    test0co.append(cosine_similarity(
    [sentence_embeddings[0]],
    sentence_embeddings[1:])[0][0])

# %%
test0['BERT Cosine Similarity'] = test0co

# %%
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
test0
# Out:
#                                                                          0  ... BERT Cosine Similarity
# 0     Malaysia regulator to probe if AirAsia broke rules in Airbus deals    ...  0.532443
# 1     FOREX-Dollar strengthens as virus fears dent risk appetite            ...  0.295684
# 2     Coronavirus conspiracies go viral on Whatsapp as crisis deepens       ...  0.123166
# 3     Fiat to Temporarily Shut Italy Plants Due to Coronavirus              ...  0.273321
# 4     Germany says coronavirus tracing app ready to go                      ...  0.260796
# ...                                                ...                      ...       ...
# 2334  FOREX-Dollar drifts as risk sentiment proves elusive                  ...  0.554289
# 2335  Fugitive ex-Nissan boss Ghosn hits out at carmaker and Japan          ...  0.450256
# 2336  Palantir Moves Toward Stock Listing With Confidential Filing          ...  0.162589
# 2337  Stocks - Europe Higher Despite Weak GDP Data; Deutsche Extends Gains  ...  0.544359
# 2338  Fines for European privacy breaches reach 114 million euros: report   ...  0.114223
#
# [2339 rows x 3 columns]

# %%
min(test0co)
max(test0co)
statistics.median(map(float, test0co))
cal_average(test0co)
# Out:
# 0.3453958670179869

# %%
inputFin= test0[0].apply(vader.polarity_scores)
outputFin  = test0['predictions'].apply(vader.polarity_scores)


comp_score_in_Fin= []
for i in range(len(test0)):
    comp_score_in_Fin.append(inputFin[i]['compound'])

test0['Inputs Vader Score'] = comp_score_in_Fin

comp_score_out_Fin= []
for i in range(len(test0)):
    comp_score_out_Fin.append(outputFin[i]['compound'])

test0['Outputs Vader Score'] = comp_score_out_Fin

Fin_diff = []
for i in range(len(test0)):
    Fin_diff.append(test0['Outputs Vader Score'][i] - test0['Inputs Vader Score'][i])

test0['Vader Score Diff'] = Fin_diff

# %% [markdown]
# **VADER SCORE COMPUTE**

# %%
test0
# Out:
#                                                                          0  ... Vader Score Diff
# 0     Malaysia regulator to probe if AirAsia broke rules in Airbus deals    ...  0.0000
# 1     FOREX-Dollar strengthens as virus fears dent risk appetite            ...  0.9171
# 2     Coronavirus conspiracies go viral on Whatsapp as crisis deepens       ...  1.0653
# 3     Fiat to Temporarily Shut Italy Plants Due to Coronavirus              ...  0.6369
# 4     Germany says coronavirus tracing app ready to go                      ...  0.2637
# ...                                                ...                      ...     ...
# 2334  FOREX-Dollar drifts as risk sentiment proves elusive                  ...  0.0953
# 2335  Fugitive ex-Nissan boss Ghosn hits out at carmaker and Japan          ...  0.0000
# 2336  Palantir Moves Toward Stock Listing With Confidential Filing          ...  0.7430
# 2337  Stocks - Europe Higher Despite Weak GDP Data; Deutsche Extends Gains  ... -0.0123
# 2338  Fines for European privacy breaches reach 114 million euros: report   ...  0.7392
#
# [2339 rows x 6 columns]

# %% [markdown]
# **FIND FLIP CLASSES**

# %%
flip = []
fromnegativetopositive = 0
fromnegativetoneutral = 0

frompositivetonegative = 0
frompositivetoneutral = 0

fromneutraltonegative = 0
fromneutraltopositive = 0

nochange = 0
for i in range(len(test0)):
    if test0['Inputs Vader Score'][i]<=-0.05:
        
        if test0['Outputs Vader Score'][i]>=0.05:
            flip.append('from negative to positive')
            fromnegativetopositive = fromnegativetopositive +1
        
        elif -0.05<test0['Outputs Vader Score'][i]<0.05:
            flip.append('from negative to neutral')
            fromnegativetoneutral= fromnegativetoneutral +1
        else:
            flip.append('no change')
            nochange= nochange+1

    elif test0['Inputs Vader Score'][i]>=0.05:
        
        if test0['Outputs Vader Score'][i]<=-0.05:
            flip.append('from positive to negative')
            frompositivetonegative= frompositivetonegative+1
        
        elif -0.05<test0['Outputs Vader Score'][i]<0.05:
            flip.append('from positive to neutral')
            frompositivetoneutral = frompositivetoneutral +1
        else:
            flip.append('no change')
            nochange= nochange+1

    else:
        if test0['Outputs Vader Score'][i]<=-0.05:
            flip.append('from neutral to negative')
            fromneutraltonegative = fromneutraltonegative+1
        
        elif test0['Outputs Vader Score'][i]>=0.05:
            flip.append('from neutral to positive')
            fromneutraltopositive = fromneutraltopositive+1
        else:
            flip.append('no change')
            nochange= nochange+1

# %%
test0['Flip Class'] = flip

# %%
test0
# Out:
#                                                                          0  ...                 Flip Class
# 0     Malaysia regulator to probe if AirAsia broke rules in Airbus deals    ...  no change
# 1     FOREX-Dollar strengthens as virus fears dent risk appetite            ...  from negative to positive
# 2     Coronavirus conspiracies go viral on Whatsapp as crisis deepens       ...  from negative to positive
# 3     Fiat to Temporarily Shut Italy Plants Due to Coronavirus              ...  from neutral to positive
# 4     Germany says coronavirus tracing app ready to go                      ...  no change
# ...                                                ...                      ...        ...
# 2334  FOREX-Dollar drifts as risk sentiment proves elusive                  ...  no change
# 2335  Fugitive ex-Nissan boss Ghosn hits out at carmaker and Japan          ...  no change
# 2336  Palantir Moves Toward Stock Listing With Confidential Filing          ...  from neutral to positive
# 2337  Stocks - Europe Higher Despite Weak GDP Data; Deutsche Extends Gains  ...  no change
# 2338  Fines for European privacy breaches reach 114 million euros: report   ...  from neutral to positive
#
# [2339 rows x 7 columns]

# %%
test0[test0['BERT Cosine Similarity']>0.6]
# Out:
#                                                                                  0  ...                 Flip Class
# 14    Telefonica Profit Miss Highlights Headwinds to Reinvention                    ...  no change
# 19    OPEC+ or minus? Oil supply cut numbers puzzle markets                         ...  no change
# 20    Food Delivery Giant Meituan's Sales Beat Estimates                            ...  from neutral to positive
# 37    Area F2 Public Beta Releases April 16th                                       ...  no change
# 46    China's Luckin Coffee says business will continue amid financial fraud probe  ...  from negative to positive
# ...                                                                            ...  ...                        ...
# 2236  China's Luckin Coffee says business will continue amid financial fraud probe  ...  from negative to positive
# 2247  Take the Money Before Things Get Worse, Junk Bond Salesmen Say                ...  from negative to positive
# 2256  Wall Street ends down in late selloff; Facebook and China weigh               ...  from neutral to negative
# 2261  Google Photos will no longer back up messaging app images by default          ...  from negative to positive
# 2291  FOREX-Dollar snaps four days of gains, but outlook bright                     ...  no change
#
# [85 rows x 7 columns]

# %% [markdown]
# #split by words

# %%
word_num_list= []
for i in range(len(test0)):
  a_string= test0['predictions'][i]
  word_list = a_string.split()
  number_of_words = len(word_list)
  word_num_list.append(number_of_words)

test0['NumberofWords']=word_num_list

# %%
frequency = {}

# iterating over the list
for item in word_num_list:
   # checking the element in dictionary
   if item in frequency:
      # incrementing the counr
      frequency[item] += 1
   else:
      # initializing the count
      frequency[item] = 1

# printing the frequency
print(frequency)
# Out:
# {13: 385, 11: 335, 8: 59, 9: 144, 15: 212, 12: 379, 10: 190, 7: 20, 16: 131, 14: 292, 24: 5, 22: 7, 17: 62, 18: 45, 6: 6, 21: 21, 20: 16, 19: 16, 5: 5, 2: 1, 4: 3, 26: 1, 23: 1, 1: 3}

# %%
mintest0bcs=[]
medtest0bcs=[]
maxtest0bcs=[]
for i in range(len(test0)):
  if (test0['NumberofWords'][i] <= 10):
    mintest0bcs.append(test0['BERT Cosine Similarity'][i])
  elif (10 < test0['NumberofWords'][i] < 18):
    medtest0bcs.append(test0['BERT Cosine Similarity'][i])
  elif (18 <= test0['NumberofWords'][i] ):
    maxtest0bcs.append(test0['BERT Cosine Similarity'][i])

# %%
properties('DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Min Number Of Words',mintest0bcs)
# Out:
# DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Min Number Of Words
# min is :
# -0.01236225850880146
# max is :
# 0.9096227288246155
# median is:
# 0.327254980802536
# average is:
# 0.3380427068734667

# %%
properties('DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Med Number Of Words',medtest0bcs)
# Out:
# DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Med Number Of Words
# min is :
# -0.026227504014968872
# max is :
# 0.7510814666748047
# median is:
# 0.34221024811267853
# average is:
# 0.34655272008494403

# %%
properties('DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Max Number Of Words',maxtest0bcs)
# Out:
# DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Max Number Of Words
# min is :
# 0.03620216250419617
# max is :
# 0.5694836378097534
# median is:
# 0.3558589816093445
# average is:
# 0.35514143767899703

# %% [markdown]
# **SHOW PROPERTIES**

# %%
print('from negative to positive')
print(fromnegativetopositive)
print('from negative to neutral')
print(fromnegativetoneutral)
print('from positive to negative')
print(frompositivetonegative) 
print('from positive to neutral')
print(frompositivetoneutral)
print('from neutral to negative')
print(fromneutraltonegative) 
print('from neutral to positive')
print(fromneutraltopositive)
print('no change')
print(nochange)
# Out:
# from negative to positive
# 634
# from negative to neutral
# 167
# from positive to negative
# 63
# from positive to neutral
# 108
# from neutral to negative
# 100
# from neutral to positive
# 588
# no change
# 679

# %%
properties('DeleteOnly FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics',test0co)
# Out:
# DeleteOnly FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics
# min is :
# -0.026227504
# max is :
# 0.9096227
# median is:
# 0.34025102853775024
# average is:
# 0.3453958670179869

# %%
properties('DeleteOnly FinancialPhaseBank Inputs VADER Score Statistics',comp_score_in_Fin)
# Out:
# DeleteOnly FinancialPhaseBank Inputs VADER Score Statistics
# min is :
# -0.9001
# max is :
# 0.8636
# median is:
# 0.0
# average is:
# -0.0812917913638308

# %%
properties('DeleteOnly yelp FinancialPhaseBank 69.epoch Outputs VADER Score Statistics',comp_score_out_Fin)
# Out:
# DeleteOnly yelp FinancialPhaseBank 69.epoch Outputs VADER Score Statistics
# min is :
# -0.7579
# max is :
# 0.9468
# median is:
# 0.4215
# average is:
# 0.35286635314236847

# %%
properties('DeleteOnly FinancialPhaseBank 69.epoch Diffirence VADER Score Statistics Bettween Input and Output',Fin_diff)
# Out:
# DeleteOnly FinancialPhaseBank 69.epoch Diffirence VADER Score Statistics Bettween Input and Output
# min is :
# -1.216
# max is :
# 1.7498
# median is:
# 0.4588
# average is:
# 0.43415814450619916

# %% [markdown]
# **SHOW PROPERTIES**

# %%
print('from negative to positive')
print(fromnegativetopositive)
print('from negative to neutral')
print(fromnegativetoneutral)
print('from positive to negative')
print(frompositivetonegative) 
print('from positive to neutral')
print(frompositivetoneutral)
print('from neutral to negative')
print(fromneutraltonegative) 
print('from neutral to positive')
print(fromneutraltopositive)
print('no change')
print(nochange)
# Out:
# from negative to positive
# 634
# from negative to neutral
# 167
# from positive to negative
# 63
# from positive to neutral
# 108
# from neutral to negative
# 100
# from neutral to positive
# 588
# no change
# 679

# %%
properties('DeleteOnly FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics',test0co)
# Out:
# DeleteOnly FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics
# min is :
# -0.026227504
# max is :
# 0.9096227
# median is:
# 0.34025102853775024
# average is:
# 0.3453958670179869

# %%
properties('DeleteOnly FinancialPhaseBank Inputs VADER Score Statistics',comp_score_in_Fin)
# Out:
# DeleteOnly FinancialPhaseBank Inputs VADER Score Statistics
# min is :
# -0.9001
# max is :
# 0.8636
# median is:
# 0.0
# average is:
# -0.0812917913638308

# %%
properties('DeleteOnly yelp FinancialPhaseBank 69.epoch Outputs VADER Score Statistics',comp_score_out_Fin)
# Out:
# DeleteOnly yelp FinancialPhaseBank 69.epoch Outputs VADER Score Statistics
# min is :
# -0.7579
# max is :
# 0.9468
# median is:
# 0.4215
# average is:
# 0.35286635314236847

# %%
properties('DeleteOnly FinancialPhaseBank 69.epoch Diffirence VADER Score Statistics Bettween Input and Output',Fin_diff)
# Out:
# DeleteOnly FinancialPhaseBank 69.epoch Diffirence VADER Score Statistics Bettween Input and Output
# min is :
# -1.216
# max is :
# 1.7498
# median is:
# 0.4588
# average is:
# 0.43415814450619916
