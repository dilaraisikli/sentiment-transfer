# %% [markdown]
# <a href="https://colab.research.google.com/github/dilaraisikli/sentiment-transfer/blob/main/Yelp_Trained_and_Manually_Labeled_GDELT_Tested_DeleteandRetrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **BERT For Measuring Text Similarity**

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 4.9 MB/s
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 47.0 MB/s
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 38.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (4.62.3)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (0.11.1+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence_transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 52.6 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 427 kB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence_transformers) (3.10.0.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (4.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 33.0 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (21.3)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 46.2 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence_transformers) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.0.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (7.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence_transformers) (3.0.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence_transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=12518a0501b55c13d72427649ab18bb0e6807eaef9588705ea17e13d083db812
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built sentence-transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, sentence-transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.15.0

# %%
import sentence_transformers
from sentence_transformers import SentenceTransformer
import statistics

# %%
import nltk
nltk.download('vader_lexicon')
from sklearn.metrics import mean_absolute_error, mean_squared_error
from nltk.sentiment.vader import SentimentIntensityAnalyzer

vader = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
def cal_average(num):
    sum_num = 0
    for t in num:
        sum_num = sum_num + t           

    avg = sum_num / len(num)
    return avg

# %%
 def properties(theString,lst):
    print(theString)
    print('min is : ')
    print(min(lst))
    print('max is : ')
    print(max(lst))
    print('median is: ')
    print(statistics.median(map(float, lst)))
    print('average is: ')
    print(cal_average(lst))

# %%
model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
import csv

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
preds = pd.read_csv('/content/preds.69',  delimiter="\t",  header=None)
test0 = pd.read_csv('/content/reference.test.0',  delimiter="\t",error_bad_lines=False,quoting=csv.QUOTE_NONE,header=None)

# %%
test0
# Out:
#                                                       0
# 0     "(Bloomberg) -- The coronavirus came relativel...
# 1     "Morgan Stanley sees balanced risks to its est...
# 2     "[Sanctions] do no good to the Chinese economy...
# 3     "Further, Wall Street has continued to show a ...
# 4     "A spokesperson for Facebook Inc. said the com...
# ...                                                 ...
# 2181  "Brazil's real dropped about 1.5% after a surv...
# 2182  "Even the unprecedented aid from the Fed and C...
# 2183  "But the WeChat ban order may be a bigger thre...
# 2184  "Microsoft Corp slipped 1.6% as its flagship c...
# 2185  "Although profits continued to grow, the legal...
#
# [2186 rows x 1 columns]

# %%
pre= []
for i in range(len(preds)):
    pre.append(preds[0][i])

# %%
preds
# Out:
#                                                       0
# 0     with others -- the open never deserved busy si...
# 1     normal whole hostess are allowing something to...
# 2     seen the thanks to see what the molly so they ...
# 3     great wall food hangout has a limited use the ...
# 4     heard on facebook reviews were just the origin...
# ...                                                 ...
# 2181  same note thinking who over a negative soup th...
# 2182  contacted the concierge boy at the most run ba...
# 2183  same issue the whole lot more you once gets a ...
# 2184  henry looks clear be done korean management fo...
# 2185  henry looks like the similar problem and the c...
#
# [2186 rows x 1 columns]

# %%
for i in range(498):
  print(preds[0][i])
  print(test0[0][i])
  print('------------')
# Out:
# with others -- the open never deserved busy since we gave moved on them and still seen the full of _num_ mins .
# "(Bloomberg) -- The coronavirus came relatively late to Yemen, but even with advance notice it has still been ravaged by the disease."
# ------------
# normal whole hostess are allowing something to blue number keep it mentioned by $ _num_ worth going to an side the opposite works .
# "Morgan Stanley sees balanced risks to its estimate that consumption will fall at an annualized 41.4% rate in the second quarter."
# ------------
# seen the thanks to see what the molly so they are clearly and give our good and his word twice .
# "[Sanctions] do no good to the Chinese economy and finance, so they do no good to the global and US economies, he added."
# ------------
# great wall food hangout has a limited use the environment in shots has wise sitting los angeles is sports night in town !
# "Further, Wall Street has continued to show a lack of confidence in the brand's ability to weather persistent challenges in North America."
# ------------
# heard on facebook reviews were just the original company had on his comments working i noticed as the spring customers closed .
# "A spokesperson for Facebook Inc. said the company had removed the accounts identified by Strick on the grounds that they were promoting spam."
# ------------
# worked us clear than regular or polite and deep commercials for things on most last couple who things for me .
# "If convicted, Najib could face hefty fines and jail terms of as much as 15 to 20 years on each charge."
# ------------
# found her okay knowing the onion mango just beware there straight note the leftovers for picking out one serious chinese food .
# "Germany's Robert Koch Institute, the nation's disease control center, recorded more than 1,000 new infections nationwide for the third day running Saturday."
# ------------
# heard the sweet number at all another professional workers close through this has of our spring restaurant has so own answer .
# "Of the plunge in manufacturing business morale, he said: ""Never in the history of a reunified Germany has it fallen so far."
# ------------
# brown then see which i keep whole loyal fish register on the va where i had getting cold root guys with the food.
# "ACRI also said concerns in Australia that science and technology priorities were being controlled by the Chinese government because funding were largely unfounded."
# ------------
# recommended her previous manager made spending the only forward more important chicken from all older hospitals by times i spent at _num_ .
# "MCD: This segment generated revenues of $401.3 million (72% of the total revenues), up 12.8% year over year but down 2.3% sequentially."
# ------------
# basic whole lot has referred a other groomers mentioned for my product that also raised his _num_ people see !
# "The U.S. dollar has been used repeatedly as a weapon against Iran against other countries and also against China, he said."
# ------------
# worked was like previous entire staff reminded me at camelback and correct explaining there by the dine planning were great !
# "He was arrested in November 2018, upon his arrival from the U.S. in Japan, thinking he was going to attend Nissan meetings."
# ------------
# lately has it close here on the two and curb things think the common open three min .
# "But lately it has been on the losing side of the same battle, as airlines rushed to buy the smaller Airbus A321XLR."
# ------------
# above and talked to be twice for another ginger lab must get down represented aspect '' at the north side brand family .
# "It is illegal to vote twice in an election, said Karen Brinson Bell, executive director of the North Carolina State Board of Elections."
# ------------
# another treatment provided such superior care in the swing like family noticed by the works of us reserved i took their john .
# "However, factors such as frequent price cuts by the government and usage of counterfeit drugs will restrict the growth of the pharmaceutical market."
# ------------
# same nice at asu 's why new sides and it starbucks than my hard guys to find a surgery _num_ are great .
# "You cannot only buy new technology and adapt it one to one, you have to drive a business transformation, said Klein."
# ------------
# a great head out enough to knock another dollar out of tea open register to end an work so be delayed in a night .
# "Aiming to head off any panic, China's government took steps to shore up an economy hit by travel curbs and business shut-downs."
# ------------
# scratch one and explain great as this knows our eye or keep up previous arrival ) are most fatty with alcoholic server ?
# "Equity markets in the Philippines and Thailand , whose central banks both meet later this week, were down between 0.4% and 0.5%."
# ------------
# another ton of different korean or our tried the ale in care those are first complaint and decently decent but our scenery .
# "A handful of those with the most significant deterioration in their underlying loans could even see their Aa rated portions downgraded."
# ------------
# reserved parking district made one like this personal than the feedback that shows up the one ordered learning layer of super rare ?
# "Industry: Air Travel Link: https://www.zacks.com/stock/news/798003/coronavirus-upends-air-travel-as-growth-slumps-to-decade-low That the rapid spread of the dreaded coronavirus (COVID-19) rattled stock markets globally is a well-known fact now."
# ------------
# read about garlic ready by brian said i asked for shows on these pieces because we noticed worthy several volumes _num_ min .
# "Although about 90% of unemployed workers in April said they were on temporary layoff, some economists worry that many won't be called back."
# ------------
# rent in the straight at a beautiful out for drop the hands with everything in the kind of it been perfect !
# "Markets in the region have taken a hit from the outbreak in China, which is one of the region's top export destinations."
# ------------
# security on the bit of tofu response but hearing insurance own great carts in their passion keep everyone is asian cat !
# "In May, the administration of President Donald Trump mandated that manufacturers globally couldn't use American technology to produce chips designed by Huawei."
# ------------
# the best thing us has been to be there to meet offers this lot of improvement -- cafe made in working such wonderful .
# "Meanwhile, the US has been struggling to come up with its own alternative to replace the products provided by companies such as Huawei."
# ------------
# add first show or returning _num_ ma deep o assistance by comes out of whole working why been 5-7 by her location .
# "(This story corrects fourth paragraph to show Turkey is import-dependent) (Additional reporting by Ebru Tuncay; Writing by Jonathan Spicer; Editing by Alexander Smith)"
# ------------
# henry is consistently odd order who got a only years note all he checks at my required rates christmas is working .
# "In China, every year has only 364 days; one day is forgotten, Taiwan President Tsai Ing-wen wrote on her Facebook page."
# ------------
# a little bit sweet or just on the much sort of chilis on saturdays i noticed the works with her then is the case .
# "There's a little bit of unease going on in the European financial markets, which is probably weighing on the euro, said Nelson."
# ------------
# overall the wildflower tips just on my favorite locale at the tanks all of that i got the shark touch up very difficult with her .
# "A music lover, the Milanese designer reacted to the cancellation of all the music festivals this summer by launching his own music event."
# ------------
# has some issues with workers than these tanks and the discounted meals of my grace do some keep these good quality products .
# "COVID-19 has caused some logistical issues but these are robust numbers, demonstrating the underlying strength of the services that are driving these investments."
# ------------
# such told me to be above the disturbing that i trust 1/2 hour of her clean toward my experience with lo back !
# "It will be pretty difficult to repeat that kind of performance again this year, added Yiu, referring to the tech sector's growth."
# ------------
# found clear beyond such a plethora of communication as my contact at reviews ordered bank within a member of those feeling room .
# "Market measures of financial health, such as the performance of bank stocks or market-based capital ratios, proved highly predictive of failure in 2008."
# ------------
# based on us the same genuinely likes on the nurses if you noted of care of each experience are so humble professionals .
# "Luckin Coffee's scandal underscored the distrust of the US financial markets of Chinese companies, as they lack on-the-ground access to the companies' books."
# ------------
# worked by the tram ' only gets on enough backs about replacing eating there are cooked and impressive sushi though .
# "In its latest report, the company missed analysts' estimates for third-quarter profit by about $1.7 billion, though it beat revenue expectations."
# ------------
# henry talk kinda than doing an buffalo beer count on tofu register for my apparently top product is great !
# "Mytheresa's flourishing e-commerce operations were not quite gelling with Neiman's own faltering online infrastructure, Ares and CPPIB said in their report."
# ------------
# normal enough about us in the drop that real open days a customer rates to getting my eyebrows is top notch !
# "It's about people--with Millennials in the lead--finally realizing that climate change is a very real threat to our lives and livelihoods."
# ------------
# previous wait with similar care of 1-2 further great service next to me except sit through a slightly grace team is available .
# "At Wednesday's auction of seven-day funds, demand fell from $36.3 billion a week earlier to $17.3 billion, suggesting a further easing of tensions."
# ------------
# worked a message for real reading a negative reviews like similar delivery center and multiple clerk mixed sales is mostly pediatric desk .
# "COVID-19 is a concern for other global auto biggies like Groupe PSA, Ford F, General Motors GM, Honda Motor HMC, Nissan and Renault."
# ------------
# always have done by my note about what my normal chili available were why of there are all through looking in tonight !
# "But in my case, like I've explained, at the same time, there are people in Zimbabwe that are losing bitcoin through bitcoin investments."
# ------------
# another wait staff for be negative or that five is working with it excellent and i noted the whole korean phone work .
# "It would be wrong for investors to be negative on these ""themes"" and Tesla is the leader in the area, Munster said."
# ------------
# out kind with note or probably with my own but at china gates that came the va such a regular gyro is great !
# "Economic data out of China, with the PMI at its weakest since the Global Financial Crisis, suggests that support is likely."
# ------------
# found on a fuzzy dominos that is n't it that has multiple issue before a truly ordered the non works .
# "(Founders Fund boasts on its website that it has never removed a single founder.) So she left the board to avoid the decision."
# ------------
# zinc was wandering by loud with the most important maintenance due an okay fish mixed speak of fucking wine with garage beyond .
# "The volume of exports was down, with the decline heavily weighted toward lower price segments, Wine Australia Chief Executive Officer Andreas Clark said."
# ------------
# worked so mad ( went at a picky co number that register are being saturday ) i got agree to a coupon .
# "10:15 a.m.  So far, a predictably uneventful day at work, I'm worried that this diary might put people to sleep."
# ------------
# called clear more closely at least thanks for how similar customer who rolled door acted like to my works straight on a dump .
# "If convicted of charges related to alleged under-reporting of former chairman Carlos Ghosn's income, Kelly could face up to a decade in prison."
# ------------
# own u own living around pretty 4-5 people in the response and $ _num_ on coming at the mini nurse .
# "Hong Kong retail investors own around one-third of the bank's total shares and lost US$1.28 billion from the latest dividend cancellation."
# ------------
# tried clear unknown than her food started like keep her dislike network alone from the discounted brand family about the return .
# "Dow Futures Rise as Joe Biden Leads Fed's sudden rate cut reflects the growing risk from the coronavirus outbreak to the U.S. economy."
# ------------
# tried on whole team here ( forgot at previous service and they scored listed that i had mostly raised at a rates .
# "Germany's Tui AG <TUIGn.DE> and Scandinavian carrier SAS <SAS.ST> also said they were suspending the vast majority of operations and seeking government aid."
# ------------
# first note with us only a number more for i 'm also forgot about working '' ordered this entrance gets young with me .
# "Brock Blake, CEO of Lendio, a marketplace for loans, also said he was hearing complaints about the SBA's computer system from bankers."
# ------------
# fired all separate years passed or handling one in my drop workers because some clearly are young top screw .
# "However, not all flights are good candidates for cargo in the passenger cabin and some airlines don't bother because loading is labor-intensive."
# ------------
# called her lab all accommodating ... my appt going longer i noticed all of there 3-4 got such a young tree dog !
# "Former Vice President Joe Biden came in fourth, a poor showing, though he still leads in most national polls for the Democratic nomination."
# ------------
# brian note advice beyond apparent response with sushi q that said up my description three of you need an formal referred friends .
# "Its dramatic success stirred concern among regulators who thought Yu'e Bao might pose a systemic risk to China's financial system, according to analysts."
# ------------
# lane vary the same at i spoke at least that with you listen brought her spa .
# "10:30 a.m.  The professor I was supposed to meet with at 11 has to bail when her childcare falls through."
# ------------
# given us agree at the dinner expecting the limited count international bar instead are open these have russian good service .
# "Obviously, given the company's share price at the moment, Wall Street isn't rewarding Cisco for its steady services growth right now."
# ------------
# included up is taking that a priority of correct up parts i noticed their same chefs offering over us .
# "It is estimated that up to 30% of the population (approximately 54,000 people) do not have piped water to their homes."
# ------------
# had the formal who fighting superior dollar service looking next at half questions that i had gone in their is our waiter outside !
# "Amgen also expects a significant impact from coronavirus-related business disruption in Q2, which it expects to ease in the second half of 2020."
# ------------
# heard product in previous such questionable call at ross on animals as however eating in a similar and an smaller than a server .
# "Ares saw a sequential decline in earnings from Q4 to Q1, although at 11% it was not as deep as many similar companies."
# ------------
# sat down as watched the whole district ordered to have true bowl of waiting which comes straight into out of his work .
# "But investors remained wary, as the number of coronavirus infections topped 350,000 and new infections brought in from abroad rose in China."
# ------------
# hire to agree serves to scream here many insurance about promised for grand asking customers for a vw knowledge or everyone !
# "Game companies are catering to existing, aging customers, having failed to effectively appeal to a younger generation or create profitable new breakthroughs."
# ------------
# stood as if im looking on her have korean fast care hotels were opening in the apparently they sign of the salsa ?
# "He said as many as 47 hotel employees who tested positive for COVID-19 were quarantined at the hotels where they worked."
# ------------
# first focus note and previous service keep a great easily the serve police are going up on feeling of a slightly working ?
# "4th quarter wage growth figures are likely to have a muted impact, with the markets more interested in sentiment towards the coronavirus."
# ------------
# like you think that there 's where with a true where on the walls within not common of india lunch .
# "Adriana: Why do you think that there is this stigma still, particularly in the south towards losing somebody to substance use disorder?"
# ------------
# great + on the above two hour expect compared to another redeeming speed was out of having a dozen stuffed that .
# "GAAP loss per share for the quarter was 48 cents, compared to a loss per share of 51 cents during the prior-year quarter."
# ------------
# worked over ( a suggestion to have the advice comes out of the caf burger is that own by new chicken .
# "As 2019 drew to a close, the company discovered ""a fault in the production line"" with its Chinese manufacturer, the CEO said."
# ------------
# many different students that have lots of decor need of your experienced honesty every other party will be treated more business .
# "And many smaller businesses and shops that have experienced extensive damage and loss of merchandise will likely need many weeks before reopening."
# ------------
# based the the kind of my problem cut their copy of those worth talking at this sort of the start .
# "In the U.S, the total number of coronavirus cases surged to exceed those in China at the end of the week."
# ------------
# called another professional chef and like previous response such prompt that filtered line multiple by getting the pass your patron time or .
# "Big Tech stocks like Microsoft Corp. (NASDAQ:MSFT) and Apple Inc. (NASDAQ:AAPL) led the decline, each closing over 2.5% lower from the previous close."
# ------------
# tried enough beyond clear at my case care but only come ordered her cheeseburger in this was somewhat answers the whole room .
# "Labour unions, traditionally strong at Skoda Auto, said it was unclear what Schaefer's appointment would mean for the direction of the Czech carmaker."
# ------------
# another manager served knew worked strange to echo some small sight where mentioned that kind of our van got an very positive stylist .
# "As Coronavirus (not yet COVID-19) jumped borders to South Korea it became clear that the first global pandemic in our lifetime was unfolding."
# ------------
# hd ) are doctors but minor be heard open back when spring orders are able they treats do n't all training .
# "Even if these restrictions are lifted, consumers won't venture out in droves unless they are confident they can do so safely."
# ------------
# either new blonde girl new human family appears from next door with out original after 10pm for normal 8:30 customers .
# "According to industrial bodies, new vehicle sales in Japan declined 10.3% year over year in February 2020, marking the fifth consecutive monthly decline."
# ------------
# tried rather whole highway and carmel chocolate which also response and insight directly on ordered lot we vary on normal inquire only .
# "JPMorgan, Citigroup and Wells Fargo & Co, which also reported results on Tuesday, collectively recognized expenses for $28 billion of losses on loans."
# ------------
# fire the constant background on top reviews of are got an professional -- the window van has prime lucky there ?
# "The current state of play, whereby no licences are concluded with Google, is an unacceptable exception, council Executive Director Angela Mills Wade said."
# ------------
# tried gone to the stand in service : plan on a down similar one on the first past a million experience .
# "Analysts expect the slowdown in service to result in a $2.07-per-share loss during the first quarter, versus a 52-cent profit a year ago."
# ------------
# normal the bar is decorated for the kind for dim means why wait is ordered a bistro pie in _num_ .
# "Once again, the bar is set high for BAC, though they are expecting a marginal year-over-year decline in EPS and revenue."
# ------------
# worked ) are fluffy looking also to get at math and only enough them by i end local working reserved is $ _num_ .
# "Computer chips are essential to modern warfare, and it's too risky to let China have a stranglehold on high-level control circuitry."
# ------------
# me as instead filing an extended warranty as similar covers for the other x $ _num_ full of doing blonde something !
# "Someone classified as an independent contractor does not qualify for unemployment insurance or for other kinds of relief programs, she says."
# ------------
# happened to contact me in such another regular and said so are also in his work to an buffalo breaks .
# "Attempting to vote twice in an election or soliciting someone to do so also is a violation of North Carolina law."""
# ------------
# apparently one along having the newest passion many more southwest than previous notice is made any been occupied feet getting us in
# "According to Johns Hopkins University, the United States has more than 3 million confirmed coronavirus cases and more than 132,000 deaths."
# ------------
# in normal and professional appt who got the experienced dark and raised the mind picture that a new by hooters new dip !
# "Markets in France <.FCHI> and Spain <.IBEX> led the decline as the two countries joined Italy in enforcing a national lockdown."
# ------------
# looked like a bowl had seen and more than mary and its on my roommate working about his 2nd place that change a raise tonight .
# "We had built something amazing, and then because of market forces and his inability to continue that culture, that got destroyed, Peck says."
# ------------
# another note the company out the healing have taken with mayo keep by this nonsense at that we got 5-7 new !
# "Most recently, the company reported a dividend yield of 4.14%, which has decreased by 0.72% from last quarter's yield of 4.86%."
# ------------
# included by the manager save a valued and careful the same ac caf is that we be slightly stuffed at first .
# "Despite an ongoing pandemic and the U.S. economy barely limping along, the Nasdaq is still trading more than 60% above its March lows."
# ------------
# another whole case started looking on a first and took extra local chicken on my case of grass is an asian stretch .
# "Late last year, Chevron took an $11-billion write-down, and a big chunk of that was from its shale gas assets in the Marcellus."
# ------------
# found it when you rather begin to teach many concept with either reserved and they had a whole difficult stuff !
# "Even when it comes to improving less advanced algorithms, researchers have struggled with limited datasets and a lack of scaleable computing power."
# ------------
# estimated notice prompt tofu same couple again apparently real substitute carrying one back keep up very particular at all .
# "John Prine (Deceased) Net worth: $10 million Singer-songwriter John Prine died of complications due to the coronavirus on April 7, Vulture reported."
# ------------
# me was told me to actually that wear a problem with my issue and i still with a manager .
# "It was huge for me to realize that there was not actually a problem with my body but with my mind."
# ------------
# by shared the norm h. korean often on the routine thursday on such a non circumstances number is .
# "- By Julie Young The Dow Jones Industrial Average closed at 28,292.73 on Thursday with a loss of 807.77 points or -2.78%."
# ------------
# props in mind hands like the only have the tofu is good despite the keep coming 1/2 the different explanation of others .
# "Fashion lobbyists in Washington have argued these tariffs are the last thing the industry needs, particularly during the stresses of the coronavirus crisis."
# ------------
# flash talk down numerous advice and again a 1/2 cooks holding joyful take negative than hers i love 1-2 .
# "A sharp downturn in later economic and corporate earnings data would likely strike a further blow to U.S. markets, analysts said."
# ------------
# worked in a few than doing the serve ok think for dozens and 3-4 trips there are always heard great share of the name .
# "Commenting in a statement, the Commission's VP for values and transparency, VÄra JourovÃ¡, added: Disinformation waves have hit Europe during the Coronavirus pandemic."
# ------------
# no follow note ( read how great with the front of me ) i noticed some people member there are free .
# "Facing pressure from regulators, mounting reputational damage and a wave of lawsuits, they warn that paying out could sink their industry."
# ------------
# note and he said the crazy understood about great rest at the counter they shape me and their office is n't .
# "But he said the government is worried about hidden cases circulating in the population and urged citizens to do their part."
# ------------
# found a basket of the same issue at a regular garlic description of over cooked on their head classes in .
# "Against a basket of rivals, the dollar index was flat at 100.02, hovering below the three-week high of 100.44 hit on Tuesday."
# ------------
# same thing in the apparently makes you just read the previous are about these small however so a beat stock bagel is superb .
# "Nations around the world are taking drastic measures to flatten the curve, but these efforts are expected to hit the economy hard."
# ------------
# mr ladies in front associates and joyful number in your previous bbq food listed by a safe know such business ordered .
# "General Motors' GM vehicle sales in China recorded the biggest-ever decline in 2019 amid a lackluster Chinese economy and U.S.-Sino trade tensions."
# ------------
# hands down a hidden off the ladies that had any short of some kind of double only an japanese corn star .
# "Due to the closure of all Primark stores, the company projects a loss of some $750 million of net sales per month."
# ------------
# whole all traveling another van side reason for the small town is a basic patron i have been .
# "For some investors, however, arriving late is a reasonable price to pay for worrying less about the possibility of a market reversal."
# ------------
# always slightly normal waiter or be ready you than to come through smelling and 's practically come here .
# "$11 10:30 p.m.  Slightly drunker than either of us want to be, so we catch an Uber home and #insertstandardMDsexstoryhere."
# ------------
# same to be the only closely at me asked for something for normal i returned in small parking has been comped .
# "He fell to the ground, asked her for help, then ran for cover in a small area housing a garbage bin."
# ------------
# tried a normal clue just in a reasonable for visiting this hooters outside of which works on nicely about _num_ young '' is very professional .
# "OPEC+ proposed a 10 mb/d in its last meeting on Thursday, but Mexico disagreed with the 400,000 mb/d it was asked to cut."
# ------------
# fire from the familiar showroom through contact that the marketing is by only the positive reviews of an awesome members often .
# "But European Central Bank board member Fabio Panetta warned that the danger to the euro zone economy is not over yet."
# ------------
# upstairs towel which used to be elderly james 's an option from two down decline after taking care of recent days ! ''
# "Anecdotally, pool builders who might typically install 20-30 pools in an average year report hundreds or even thousands of quote requests."
# ------------
# realistic there ( have constant sole '' such on other stick in the similar assigned keep a few dish 's by name !
# "(See Netflix stock analysis on TipRanks) Spotify Technology (SPOT) In a similar vein to Netflix, Spotify's ascent has disrupted a whole industry."
# ------------
# another positive product at the vegetable curry keep returning at the bottom draw comes out due an semi for a new license .
# "But market pundits ignored the overall drop in service industry employment last month, citing an increased employment in six major non-manufacturing industries."
# ------------
# us we keep of impressive who is n't remotely on my resolution of and say i had 3-4 queen .
# "Because we fail to recognize that models are not a report sent back from the future,"" according to journalist Jonathan V. Last."
# ------------
# found passed so note so that my team are a worthwhile either and maintenance this is my previous cars on the office .
# "9:30 p.m.  B. is late so I sneak a peek at his phone location using the tracker thing on our iPhones."
# ------------
# tried clear whole prescriptions ( read her many other bottom and stayed working open by and he was hella whole with manager .
# "In Europe, Germany's DAX tumbled 3.9 percent while Britain's FTSE and France's CAC were lower by 3.2 percent and 3.4 percent, respectively."
# ------------
# stood everything also extensive just the need of diner included and i argue with advice about one '' customer with the way workers .
# "He also stressed the importance of building a relationship and trust with customers because it dramatically affects the reputation of the brand."
# ------------
# previous issue or the similar with your onion are available at this is after coming to get a nail there 's quick .
# "For now, any threat to the current political settlement is unlikely to come from a resurgence of the popular Islamic movement."
# ------------
# united servers currently written longer reflect her s like there for internet and register comes all about her ordered my onion in ( .
# "The United States is targeting senior Iranian officials for their involvement and complicity in Tuesday's ballistic missile strikes, Mnuchin said in the statement."
# ------------
# brief ( and in the east valley drop are numerous sales one on only separate of the name needs .
# "Continued violence and terrorism in the Middle East and other parts globally are also expected to have a negative impact on the market."
# ------------
# sat was well before the workers i give an upgrade of my technician fixed good mexican instructor they made by previous great job .
# "A few said they feared the company would slip into a state of inaction they believed had characterized Yusupov's tenure as CEO."
# ------------
# cleaner and cried at me looks at my frank and switch chicken i had his shots at her cal amount !
# "I cried and cried at my father's shoulder as he walked off the first flight he had ever taken, at age 59."
# ------------
# after the window the hotel have great locale at what 's over clean down six with new low pieces are restaurant open !
# "In Japan, the hotel room count has stalled at little over 5,000, with just over 300 new rooms added in December."
# ------------
# tried clear passion like us based on my many and polite for tune for lo parts also for referred employee young or never .
# "High research and development expenses on advanced technologies for the development of EVs and driverless cars are also likely to dent near-term margins."
# ------------
# slightly came at it was gone in with garlic value of tables except fell worth hundreds of stuffed everything !
# "EPS was slightly disappointing  it came in at just 2 cents per share compared to the forecast of 8 cents."
# ------------
# same counter prior at least others updated at her and ordered from dozens of tables based within far as spa and beyond .
# "In response, JetBlue plans to reduce capacity by at least 40% in April and May, with further cuts likely in June and July."
# ------------
# same had to report has found their power for hanging in streets of rules waiting in a tradition of her city !
# "Audi has had to slow down production of electric cars at its plant in Brussels due to a battery cell shortage."
# ------------
# great bartenders and scream up based on the friendlier filtered office have mentioned on it by the latest has consistently ton of order .
# "ByteDance Plans Assault on Tencent's Mobile Gaming Kingdom The enterprise software market in China is lagging the U.S. by at least 10 years."
# ------------
# worked note with few times i just remember if you pull on my move along and travel great to people !
# "9:45 a.m.  We're about to leave when I remember I'm supposed to pick some things up from school at 10!"
# ------------
# us shared wicked apple new then apparently had these customers to disappear the pork carefully of her sign was a magazine .
# "In China, meanwhile 800 new cases were reported overnight, taking the total to 75,000 confirmed cases and the death toll above 2,000."
# ------------
# great production specials still be visible at what far enough dude starting to got away working there are home .
# "Harvard epidemiologist Marc Lipsitch also warned that too little is yet known about post-infection immunity to assume people can't get re-infected."
# ------------
# love the aroma in shock similar food at this location soon speaking of the fine dishes i sort looking got on blackened .
# "End-Market in Detail Texas Instrument's revenues were down 40% in the automotive market on year-over-year basis owing to ongoing coronavirus pandemic."
# ------------
# with above tips here as well getting the security fly out case with there for coconut onion was over in .
# "Along with shuttered businesses around the world, Tesla's sole US factory in Fremont, California, was shut down for much of the quarter."
# ------------
# brian was ( even gotten you like the cherry offer you if you raised up by the onion drop a man !
# "We were smarter than the underfunded schools you put us in, but you had your knee on our neck, Sharpton said."
# ------------
# called the biggest manager made me that we ordered for hired previous food on works ) portioned full of the vehicles friendly at all .
# "Among the biggest gainers were those that had fared worst in 2019, with banks leaping as bond yields hit their highest in months."
# ------------
# tried starting worked thinking about cooked quick have gone else soon explained things because there movie is very living in _num_ .
# "Downside risks: 1) 70%+ seat penetration in CRM could limit growth while declining sales headcount in Life Sciences may be a headwind."
# ------------
# odd looks together and be switching they are running standard -- has the display choice thing add and actual check-in goes a blast !
# "Intel has faced more competition as its lead in production technology -- a key way to improve semiconductor performance -- has slipped."
# ------------
# has another whole advice beyond an superior hour in the tips are one because i moved at the terminals shaved are awesome !
# "COVID-19 has triggered an across-the-board sell-off in financial assets, and one of the hardest hit sectors among equities is the Internet space."
# ------------
# estimated in tee note ... be 4-5 1/2 carts goes right despite a dozen manicures for that my sushi was booked .
# "Government lawyers estimated in court papers that it would cost taxpayers between $5 million to $7 million for every month implementation was delayed."
# ------------
# contacted any more dry than her gucci and hire more tofu airlines on note he hotels of screaming my head at all night .
# "Due to shrinking top lines, heavyweight airlines including Delta Air Lines, American Airlines and United Airlines incurred losses in the June quarter."
# ------------
# same bright in a professional manor at all security and claim talking here like the register they raised parking has been a yr .
# "In a country versed in disruptions from wars and security threats, he said Israelis have built up a certain resilience to upheaval."
# ------------
# tried like helping have to verify the diner then stocked because he raved of all i raved over her goes to make this sweet staff .
# "I don't have to finish updating the slides until next week, but I don't enjoy making slides and want it to be done."
# ------------
# found us insane number longer beyond with the popular serve for three levels on my highlights for their second time down .
# "As such, Goldman lowered its year-end forecast for the S&P 500 and trimmed profit estimates for the second time in a month."
# ------------
# okay ( note that said spanish based thinking enough included i gotten very good factor to make my first party are the science .
# "Meadows said earlier Thursday that he's concerned that Oracle's bid for TikTok may be a repackaging that won't meet the president's goals."
# ------------
# us pay suits basic korean soup we have gone down form that 's previously offer different about a couple grill of _num_ staff !
# "However, China's physical aluminium processing chain itself has been shaken, which may translate into different outcomes at different stages of the value chain."
# ------------
# maybe they have researched for us like since had another working on the sunrise by fine about the two lot five min .
# "McKinsey says battery costs have fallen about 80% since 2010, and they're expected to decline by another 50% in the next few years."
# ------------
# another whole favorite ( earth looking like he keep looking like carrying pricey and we drop ahead of mildly ignored in the fashion grey .
# "A slowing global birthrate has hit P&G and competitors like Huggies diapers maker Kimberly-Clark <KMB.N>, particularly in China and the United States."
# ------------
# prior as talked by a certain i like checking these beans on the rest serves name there within this facilities problem .
# "Consumption remained restrained in China this summer, even as other parts of the world's second-largest economy picked up as lockdowns eased."
# ------------
# based that clearly popped in general oil shows into it with everyone about our next to be combined of everything !
# "Consider that Google has hardly covered itself in glory when it comes to being honest about its use of our location."
# ------------
# instead of the manager understood about my serve here as important in the pull 30+ minutes for prime to bravo new !
# "Bear of the Day: NETGEAR, Inc. shares have tumbled 31% in the last six months, as its sales continue to decline."
# ------------
# up talking our inspection is the only chance we are recommending to have one checks to know my worked about gold van !
# "Tomorrow we'll be releasing the documents and people will be able to see there's a very detailed dispute resolution process, he said."
# ------------
# dessert smells by comparison of management due to those sort of pleasant pass by overpriced business makes up brewed sort of smokers visit .
# "M&A volume fell 72% in Latin America to $10.8 billion, according to Refinitiv data, with Brazil hitting its lowest volume since 1999."
# ------------
# found the one is just try of a geek knowledge that are carrying passed out of the positive which s an recent owner !
# "This is one of the strongest storms to impact that section of coastline, said David Roth, a forecaster with the National Weather Service."
# ------------
# since the second encounter with the regular salon just keep blowing line by about a second of her only been a manager .
# "Currencies since the start of the year https://fingfx.thomsonreuters.com/gfx/mkt/zygdpzbqpwa/Pasted%20image%201585492388471.png Brent crude oil has fallen by 62% in the quarter to just $25 a barrel."
# ------------
# definitely pay after ten dollars on two hours who ordered work within one unless i signed and there are totally .
# "$570 6:30 p.m.  After spending two hours unpacking and putting together the new apartment, K. and I are tired and hungry."
# ------------
# up with another drop hour performances running like its my moving mozzarella to pay for getting a lot of iceberg lettuce .
# "Even with thousands fewer flights every week, the airline expects its planes to be only 20% to 30% full at best."
# ------------
# considering the whole staff was more where the late serve either called the attire for been going through a tech .
# "But the economy was slowing even before the Covid-19 pandemic hit the U.S., and the last five months have been devastating."
# ------------
# best gates in me crazy china there for the couple nearby and stands fair compared to be both final cocktail prices !
# "Elsewhere, Germany posted its slowest growth in six years and the U.K. seems certain to cut rates after inflation hit a 3-year low."
# ------------
# next to be coming more just through another soul food in the earth = after pictures are taken to need out a smile .
# "They're going to be an even bigger nonfactor in 2020, financially. In 2016, the group spent more than $50 million to help Republicans."
# ------------
# previous whole suggestions about manager never read all especially the other welcome i watched child on their entire family for the weekends !
# "Last month, protesters shouting about police brutality swarmed Mast and other guests of the Republican National Convention as they left the White House."
# ------------
# sat across this seemed by a minute for the similar one these work selling the airport '' has an knowledge artist customer !
# "Last week, an article in The Lancet article, a medical journal, prompted the World Health Organization to halt its trials on hydroxychloroquine."
# ------------
# start off the apple closer member its appropriate india for another bread working in my case asking they truly count of customer owners !
# "At least one former Enphase distributor in India terminated its relationship with the company due to concerns over potentially fraudulently inflated invoices."
# ------------
# same a great chat with her which 's like numerous delivery that exception of the usually included a wide blast .
# "It's a stark contrast with Tesla, which suffers from the inverse problem: a lack of oversight for its brilliant but flawed CEO."
# ------------
# worked out overall gained on five minutes to verify my ramen al than _num_ 1/2 in whole dishes of shots is a server .
# "Mining was temporarily suspended from March 20th due to a nationwide mandatory quarantine imposed in Argentina to combat the spread of COVID-19."
# ------------
# eel full of my waiter added superior care at 2am ) have an automatic register compared to a cats of yelp .
# "A combination of the virus's properties, an overwhelmed health-care system and systematic neglect have taken a brutal toll on the elderly."
# ------------
# same a note which takes her that the manager o keep coming out posted for asking to be only common cocktail than one !
# "It's a survival package, he said, predicting that business closures and stay-at-home orders are likely to be necessary for at least two months."
# ------------
# another note enough looks at several street out only greasy degrees out starting on an few hour upon in others .
# "MSCI's broadest index of Asia-Pacific shares outside Japan wobbled 0.1% higher by late afternoon after falling more than 5% in morning trade."
# ------------
# uncle hope stopped as recently or their charge on my opinion and had raving about 1/3 of things i been at happy hour .
# "My parents still claim me as a dependent on their taxes but haven't paid for any of my expenses since then."
# ------------
# brief note of the group is at a bk place enough then that was her work when an awesome time .
# "Next Steps: Although the valuation of a company is important, it shouldn't be the only metric you look at when researching a company."
# ------------
# already looking for returning one feel as when i want by standing there have been clear the rest up six of van is unbelievable .
# "I'm going to continue working as long as I can, out of necessity, said Pupo, wearing his uniform, a scarlet jacket and cap."
# ------------
# eric ) reserved their be recent topping at all doctors own , correct fan as had our mixed business up photo house .
# "Japanese game designers are slowing their pace of producing new loot -- because quality expectations have ballooned while their development teams have not."
# ------------
# rent -- molly filler us have issues for the polite tanks and get thru whole table overall i offers an here confused .
# "However, ongoing reputation issues and unresolved legal matters have weighed on the bank's stock price and profitability, which have lagged peers since 2016."
# ------------
# tried clear don received a breaded professional who the important carts on one i see iced stuffed professionals .
# "Ask the guys at Porta dos Fundos, the irreverent comedians who released a Yuletide parody on Netflix featuring a gay Jesus."
# ------------
# same a step above being appropriate hour due for about a draw out the cutest of _num_ by nurse but i love this place !
# "However, a drastic increase in provision for credit losses due to the impacts of the coronavirus outbreak was a major offsetting factor."
# ------------
# talk the breaded at me and similar food enough numerous page for us beach close to customer the first stuffed at best .
# "During the Republican and Democrat primaries, over 550,000 mail-in ballots were rejected, compared to 319,000 during the entire 2016 general election."
# ------------
# stood there made math by you can have been a register lines for learning one by waiting straight here with the bad .
# "The economic data shows there is still a challenge going forward, said Willie Delwiche, an investment strategist at Baird in Milwaukee."
# ------------
# julio agent are reading the slightly rated advantage of garlic but why bring the prime over such his 2nd time , family .
# "The banks are engaging in double standards, Marlon Vargas, president of the Confederation of Indigenous Nationalities of the Ecuadorian Amazon, told Reuters."
# ------------
# julio coworkers see dirt like a popular number numerous food and be on the pull sign of plan @ _num_ on the time .
# "2 consecutive weekly jobless claims increases and a 32.9% contraction in the U.S economy weighed on risk appetite at the month-end."
# ------------
# tried clear eating chef with a second co and the open grocery soup then non works for some gold address .
# "But amid rising U.S.-China tensions, the White House has threatened to ban TikTok and other Chinese-owned apps, citing national security risks."
# ------------
# called clear manager that they have give my younger rave enough instead accompanied the hunt we void of mad friendly this .
# "In May, they said that they would not pay their planned ordinary dividend on 2019 results, citing the negative impact of the pandemic."
# ------------
# beyond have found this neighbor after the experienced facilities stand by their fact why they got on the young appt .
# "Alen has been deeply disappointed in the government's attitude toward restaurant culture, and how this reflects on the country's lockdown policy."
# ------------
# security register means perfect but guests see them properly longer ideas and careful with her shots were overly helping me one tonight .
# "Many companies haven't figured out yet how to accommodate pause revenue, and billing systems were hard-wired without that concept, he said."
# ------------
# her then similar close to be thanks about and have a ton of themselves ordered it keep was very limited large sushi .
# "But recessions tend to be good for MLMs, and this recession shows no sign of abating as new COVID-19 outbreaks slow reopenings."
# ------------
# add a different looking added back than any real onion '' and comes to draw out at getting minor very good server .
# "(n.) Something added to a situation, company, deal, object, etc., to make it undesirable to takers, buyers, thieves, investors, or conquerors."
# ------------
# mentioned another cool claims to the harley given the taste of bbq comes on a pools 's an unexpected restaurant still smoking .
# "Beijing re-imposed measures to curb the spread of the virus after a wholesale food market saw an unexpected spike of cases."
# ------------
# same issue the friend found a regular of us further of pace by another dominos for a normal great types too !
# "Beijing this week accused the US of sending a U-2 spy plane into a no-fly zone over Chinese live-fire military drills."
# ------------
# an production with just be there at the prices straight right signs because was there taking out were a plane .
# "However, an investor who was oblivious to the noise and did not act on sentiment would now be sitting on unprecedented returns."
# ------------
# ...
# "Brexit concern is holding back the pound with German Foreign Minister Heiko Maas saying there was a growing risk of a hard Brexit."
# ------------
# phenomenal buyer provided people else normally grab the item reserved in a fairly generous and original beverages .
# "It remains to be seen whether Cheesecake Factory can still turn a profit given the reduced seating and high overhead costs."
# ------------
# previous nonsense note just getting on my services are open but one on the prior of grooming was different .
# "In addition, Zhou warned, China should brace for a worldwide food crisis and the return of international terrorism during the pandemic."
# ------------
# found out doctors than last ten care of a gluten-free trend we said signs by a sudden that vet gets a smile with the kids .
# "In 55 years of soap-making, Globo faced a shutdown only once, in 1975, when the military dictatorship censored a novela it found seditious."
# ------------
# security next single room was so much if i hesitate back via 2am except that a copy guard my visit _num_ spa .
# "Analysts cheered the new targets, after repeatedly asking management when Morgan Stanley might upgrade them, since the bank was routinely meeting previous goals."
# ------------
# nice outdoor acts and gives a company keep my dairy manager is and they handled so a heavy for my own glass staff ?
# "Disclaimers:Soulstring Media Group and its parent company is not operated by a licensed broker, a dealer, or a registered investment adviser."
# ------------
# another friend on the daughters just a patient in his menudo joint because i mentioned bringing the front on pain kind of year !
# "After taking the drugs with a girlfriend in his apartment late that night, the next day police found Kroll dead in his bed."
# ------------
# security for full more times than what i even bring my servers there are some passion for any attitude of their patrons atmosphere .
# "It's free for 90 days and even though I don't have a bike or treadmill, they offer other classes that are pretty challenging."
# ------------
# in a competent competitive of make her egg or longer network and similar shots for between my office being peeve behind .
# "Negotiations of a new UK-EU trade pact have stumbled, and Britain's requests for direct financial market access are being separately by Brussels."
# ------------
# tried previous chef just dignity form me owned supporting means a ton aside in my second about each last time was the coupon .
# "By Geoffrey Smith Investing.com -- China's economy shrunk, as expected, in the first quarter for the first time in three decades."
# ------------
# worked off beyond accurate as somewhat approved within my $ of house from this slightly issue gets a 1/2 star knew .
# "Around 400 patients were hospitalized between June 7 and June 13, a jump of nearly 30% from a week earlier, the report said."
# ------------
# i called up on previous as i give to this rave at their hard reviews than 2nd ) was ready at review feeling from this point .
# "Continuing to advertise on these platforms at this time would not add value to people and society, Unilever said in an emailed statement."
# ------------
# hands the bit super down the african like the clinic keep it on a open review by spending your popular appointment 's times !
# "Given the extremely short-term nature of the trade, it's unlikely the trader is making a bet based on Nvidia's long-term fundamentals."
# ------------
# went short working me familiar but an usually polite but now for top of once have an already chat talk of us .
# "I know 11 won't sound late to many people, but I feel awful if I don't get at least eight hours of sleep."
# ------------
# same friendly and use in a number of my rates are on the panera but straight description the _num_ star .
# "We have sustained damage in a number of our stores and are assessing the impact overall, a Macy's spokeswoman told WWD."
# ------------
# great image that at us are still such a better from the nice considering i rolled the checks of the previous primary customers .
# "Hill believes that we are looking at a probably recession, along the lines of the one following 9/11, or the 2008 financial crisis."
# ------------
# pleasant hope and we have that a maintenance makes a second top as represented that we needed is a genuinely more !
# "My hope is that we have a recovery and it's a slow and steady recovery so that the cycle can be more elongated."""
# ------------
# based thinking by these dental now is about coming of signs these separate customers think i coming to wear warner the staff .
# "So knowing now that part of these attacks are coming from people directly related to the Bolsonaro family, that explains a lot."
# ------------
# worked on super as they multiple at what they are heard properly counter only review charge her over the former hour as _num_ .
# "Analysts were very bearish on the stock as recently as 30 days ago, but have dramatically changed their tune over the last week."
# ------------
# called of couple of four earlier you guys particularly moving the register of this positive number was delivered .
# "As of 2009, three to four million Zimbabweans  the greater part of the nation's skilled workforce  had left the country."
# ------------
# found an professional skills like any have a paying priority with these open comes that a second waiter goes on an odd selection .
# "He has downplayed any pressure from Elliott, a New York-based activist investor that disclosed a nearly $3 billion stake in SoftBank this month."
# ------------
# same recommended the manager who i get those care that others are out to me on her attention to work with a manager .
# "Now the same people who ignored me are the ones that reach out to me to help them with their business."
# ------------
# another favorite of that shows learning that has become my tough noodles on the elevator in a stretch of tanning office and greeted .
# "Control of data that hurts competition has become a critical topic in the antitrust debate in the United States and Europe."
# ------------
# sat upstairs recently both just see this 3rd and d for bbq open and there are the most minor idea that decision !
# "Morgan Stanley recently downgraded both DraftKings and Penn National and said expectations for the sports betting and iGaming markets could be high."
# ------------
# once clear count by the `` important for his reviews which i sold on front is continue to receive quality is slow .
# "But while Thompson believes regulatory scrutiny of the platforms is reasonable, he sees risk in giving regulators and politicians more control of media."
# ------------
# called her staff would give so any better if he signed talking for it were very tender ( at bravo '' to manager .
# "Daraz told Reuters it would to take ""necessary action"" if the listings were found to violate its policies or harm customers."
# ------------
# tried ( count on previous like a toyota york ac for prom house by the kind with mobile showroom is taken .
# "China's ceremonial legislature on Thursday endorsed a national security law for Hong Kong that has strained relations with the United States and Britain."
# ------------
# same sales look closely farm that open each as long the 2nd work on the power india serving is delicious cookies .
# "Crude prices suffered another sharp fall on Monday as the pandemic worsened and the Saudi Arabia-Russia price war showed no signs of abating."
# ------------
# next the whole lamp several back only visitor with others have great shape down them takes our is her free instead .
# "Over the last several months cybercriminals have targeted hospitals with computer viruses, usually in schemes to extort them or hold their data ransom."
# ------------
# made us have constant rule form : many separate pieces of $ _num_ by albertsons out got a ton of our typical lease .
# "Cathay Pacific's stock has slumped 21 per cent since unveiling its June 9 recapitalisation plan, a reminder of the industry's continued struggle."
# ------------
# in customer service as the best vets but this add plus they have a slightly ten advice !
# "Believing in hard work and customer service as the core objective, they have achieved a flawless reputation within a short span."
# ------------
# same the blonde knowledge here the passion for 3-4 care the third procedures by me within a ton excellent starters at excellent service .
# "In the U.S., new motorcycles sales didn't weather the last recession very well, dropping 50% in 2008 and remaining stagnant since."
# ------------
# found our business band to the continue important at them ask : both checks with a description and other volcano behind burgers .
# "As our business continues to grow rapidly, the operational complexity also increases, said Peter Maag, Chairman and Chief Executive Officer for CareDx."
# ------------
# tried up on us tomato others thinking you needed orders are similar because of her consistent about been hella _num_ .
# "For Intel, we've put together three essential items you should assess: Risks: Consider for instance, the ever-present spectre of investment risk."
# ------------
# fair work and keep your poop and chaos from the landscaping to stand has out one for a eye working in ?
# "1 energy consumer and road, rail and air transportation has virtually come to a standstill in infected parts of the country."
# ------------
# great number beyond tips by a hurry if we cared of butter lets get in generous for a pic of tests .
# "As Deutsche Telekom's dividend was not well covered by earnings, we need to check its balance sheet for signs of financial distress."
# ------------
# called to say im taken here on normal many scrub charge of the terminal only that a friend post her ?
# "It is not possible to enable E2E encryption for Zoom video meetings, a spokesperson told the website in a statement earlier this week."
# ------------
# more first section if talking to the health from open and the male patient issue i made my initial work with saying .
# "The more that public opinion shifts from the health to the social and economic crisis, the more Conte risks losing consensus, said Pregliasco."
# ------------
# tried certain beyond singing just as sometime for joyful charge sometime if of previous food '' has raised above _num_ overall .
# "Lufthansa shares fall 3.8% as Germany may extend some travel warnings to August 3; Zara owner Inditex booked its first-ever quarterly loss."
# ------------
# normal counter beyond at me received such kind at like vet working available like it ordered several shrimp close at _num_ min .
# "Germany's benchmark 10-year Bund yield was at -0.453% at 0700 GMT, down 2 bps but still trading within the week's range ."
# ------------
# next past the week with previous quote of the open $ _num_ more than counter by a former drop of offered nothing .
# "In the past week (as of Feb 27, 2020), the key U.S. indexes lost more than 11% and entered into the correction territory."
# ------------
# note eddie see those kay responded too familiar & servers accompanied the manager make up of prime during the friendly service .
# "Basketball players Kevin Love and rookie Zion Williamson supporting arena workers who've lost their jobs or hours by the NBA season being canceled."
# ------------
# another message is the professional company see that serves fighting two ; ) by the staff is still the latest and had more cat !
# "Kalton said the company is facing both financial risks and risks to its reputation, but the 20%-plus sell-off is likely an overreaction."
# ------------
# same slightly recommended # _num_ plus for the long go by only one yelpers included right on shadyside of the plane was broken .
# "AIA's shares fell 4.4 per cent to HK$68.8, while the benchmark Hang Seng Index closed 3.7 per cent lower at 24,309.07."
# ------------
# prior to the gold 's had more sort from through eye pieces of insight that required to be read $ _num_ full .
# "According to Caixin, the fake gold was exposed in February when Dongguan Trust set out to liquidate Kingold's collateral to cover defaulted debts."
# ------------
# out of bit on any more of you have talking enough of tai words be that standard sam or one ?
# "The slightest bit of bad news on any of these factors could be enough to cause further volatility in the markets, he added."
# ------------
# bottomless whole team with decent airline at ron just a oh yelpers of only get dozens of us roughly a veggie treat .
# "Its local securities unit, however, has revenue of just 132 million yuan, posting a loss of 109 million yuan last year."
# ------------
# great given by the chef made all like the open living fans at all on there ear and raised grace are awesome !
# "Factories in Poland, including the e-CVT hybrid gearbox plant in Walbrzych and the hybrid engine plant in Jelcz-Laskowice, also halted operations on Wednesday."
# ------------
# showed out there skills at gold services that provided an average grocery bikes as worked working within one of a straight problem i was great .
# "Data showed that Brazil's services activity slumped at a record pace in April, although analysts expect an eventual recovery as virus-led lockdowns ease."
# ------------
# rent above by smooth after the humble holes what the standing combined behind the about the couple that got great at .
# "Eminence performance rebounded slightly by the end of the month, putting the fund down 19% for the first quarter, according to the investor."
# ------------
# nice man talk to see about the dancer that i works is sealed i seen for his cut 's a nice experience .
# "When people start to see that the growth is slowing, we think it becomes a real problem for Tesla, he said."
# ------------
# mentioned just being gentle the concierge this wonderful attorney of yellow shock like the register and capable three each for me .
# "I'm not pleased with where the senior leadership of the firm is, Solomon said of the bank's predominantly white, male senior ranks."
# ------------
# previous note the whole food ) become great either of the only close to on the dr of such a reception kids !
# "In addition, the rising environmental challenges also pose a major threat to the growth of the global market for animal nutrition."
# ------------
# above all of odd looks worth calling for being working with side dishes are think she ended up her two times are on us !
# "One of Twitter's bigger challenges with its take on Stories is figuring out which Fleets will be displayed first on your home screen."
# ------------
# based know the same deserved that thanks with your name noodles and on my work which was only client of acceptable prices !
# "But critics say the antitrust crackdown is being enforced unevenly, and that the business environment for overseas companies is worsening as a result."
# ------------
# another whole spaces with handicapped many healthcare house and punch by the keg of their dining floor were .
# "Malta turned away another cruise ship and some airlines, including British Airways and Air Canada, canceled flights to the whole country."
# ------------
# found more on spending more than have on their onion rings at reviews and one ) took forever to go to all .
# "Airlines are spending more on refunds than they're earning on new bookings, and airline executives say their companies could take years to recover."
# ------------
# other servers name looked important that read my hotel back and mentioned all what they were only makes jose fairly cool pup .
# "Its sales could fall 53% this year to $22 billion and earnings will be negative, but conditions are also expected to improve dramatically."
# ------------
# sat during another week for working but another month drop soup means asking $ good they are first priority and same .
# "Even during the worst week for stocks since 2008, Buffett said long-term investors shouldn't be stressing out too much about news headlines."
# ------------
# elevator by the va garcia would have been in korean about free beans that my 2nd would receive my volleyball sushi in .
# "BT's leading position in the U.K. communications market would be threatened by a merger of rivals O2 and Virgin Media, we believe."
# ------------

# %%
test0['predictions']= pre

# %%
test0co = []
for i in range(len(test0)):
    sentences = [test0[0][i], test0['predictions'][i]]
    sentence_embeddings = model.encode(sentences)
    test0co.append(cosine_similarity(
    [sentence_embeddings[0]],
    sentence_embeddings[1:])[0][0])

# %%
test0['BERT Cosine Similarity'] = test0co

# %%
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
test0
# Out:
#                                                                                                                                                        0  ... BERT Cosine Similarity
# 0     "(Bloomberg) -- The coronavirus came relatively late to Yemen, but even with advance notice it has still been ravaged by the disease."              ...  0.573650
# 1     "Morgan Stanley sees balanced risks to its estimate that consumption will fall at an annualized 41.4% rate in the second quarter."                  ...  0.355409
# 2     "[Sanctions] do no good to the Chinese economy and finance, so they do no good to the global and US economies, he added."                           ...  0.108376
# 3     "Further, Wall Street has continued to show a lack of confidence in the brand's ability to weather persistent challenges in North America."         ...  0.372849
# 4     "A spokesperson for Facebook Inc. said the company had removed the accounts identified by Strick on the grounds that they were promoting spam."     ...  0.667993
# ...                                                                                                                                               ...     ...       ...
# 2181  "Brazil's real dropped about 1.5% after a survey showed the country's service sector confidence in March plunged at its fastest rate on record."    ...  0.482084
# 2182  "Even the unprecedented aid from the Fed and Congress won't be nearly enough for households and businesses to weather a protracted downturn."       ...  0.278853
# 2183  "But the WeChat ban order may be a bigger threat as there doesn't seem to be an obvious way out before the deadline."                               ...  0.624048
# 2184  "Microsoft Corp slipped 1.6% as its flagship cloud computing business Azure reported quarterly sales growth of under 50% for the first time ever."  ...  0.290624
# 2185  "Although profits continued to grow, the legal and regulatory scrutiny around the company clouded its future, and shareholders paid the price."     ...  0.297085
#
# [2186 rows x 3 columns]

# %%
min(test0co)
max(test0co)
statistics.median(map(float, test0co))
cal_average(test0co)
# Out:
# 0.4149851586366343

# %%
inputFin= test0[0].apply(vader.polarity_scores)
outputFin  = test0['predictions'].apply(vader.polarity_scores)


comp_score_in_Fin= []
for i in range(len(test0)):
    comp_score_in_Fin.append(inputFin[i]['compound'])

test0['Inputs Vader Score'] = comp_score_in_Fin

comp_score_out_Fin= []
for i in range(len(test0)):
    comp_score_out_Fin.append(outputFin[i]['compound'])

test0['Outputs Vader Score'] = comp_score_out_Fin

Fin_diff = []
for i in range(len(test0)):
    Fin_diff.append(test0['Outputs Vader Score'][i] - test0['Inputs Vader Score'][i])

test0['Vader Score Diff'] = Fin_diff

# %% [markdown]
# **VADER SCORE COMPUTE**

# %%
test0
# Out:
#                                                                                                                                                        0  ... Vader Score Diff
# 0     "(Bloomberg) -- The coronavirus came relatively late to Yemen, but even with advance notice it has still been ravaged by the disease."              ...  0.0000
# 1     "Morgan Stanley sees balanced risks to its estimate that consumption will fall at an annualized 41.4% rate in the second quarter."                  ...  0.5692
# 2     "[Sanctions] do no good to the Chinese economy and finance, so they do no good to the global and US economies, he added."                           ...  0.4900
# 3     "Further, Wall Street has continued to show a lack of confidence in the brand's ability to weather persistent challenges in North America."         ...  0.2070
# 4     "A spokesperson for Facebook Inc. said the company had removed the accounts identified by Strick on the grounds that they were promoting spam."     ... -0.0430
# ...                                                                                                                                               ...     ...     ...
# 2181  "Brazil's real dropped about 1.5% after a survey showed the country's service sector confidence in March plunged at its fastest rate on record."    ... -0.7369
# 2182  "Even the unprecedented aid from the Fed and Congress won't be nearly enough for households and businesses to weather a protracted downturn."       ...  0.7096
# 2183  "But the WeChat ban order may be a bigger threat as there doesn't seem to be an obvious way out before the deadline."                               ...  0.1657
# 2184  "Microsoft Corp slipped 1.6% as its flagship cloud computing business Azure reported quarterly sales growth of under 50% for the first time ever."  ...  0.0338
# 2185  "Although profits continued to grow, the legal and regulatory scrutiny around the company clouded its future, and shareholders paid the price."     ... -0.5455
#
# [2186 rows x 6 columns]

# %% [markdown]
# **FIND FLIP CLASSES**

# %%
flip = []
fromnegativetopositive = 0
fromnegativetoneutral = 0

frompositivetonegative = 0
frompositivetoneutral = 0

fromneutraltonegative = 0
fromneutraltopositive = 0

nochange = 0
for i in range(len(test0)):
    if test0['Inputs Vader Score'][i]<=-0.05:
        
        if test0['Outputs Vader Score'][i]>=0.05:
            flip.append('from negative to positive')
            fromnegativetopositive = fromnegativetopositive +1
        
        elif -0.05<test0['Outputs Vader Score'][i]<0.05:
            flip.append('from negative to neutral')
            fromnegativetoneutral= fromnegativetoneutral +1
        else:
            flip.append('no change')
            nochange= nochange+1

    elif test0['Inputs Vader Score'][i]>=0.05:
        
        if test0['Outputs Vader Score'][i]<=-0.05:
            flip.append('from positive to negative')
            frompositivetonegative= frompositivetonegative+1
        
        elif -0.05<test0['Outputs Vader Score'][i]<0.05:
            flip.append('from positive to neutral')
            frompositivetoneutral = frompositivetoneutral +1
        else:
            flip.append('no change')
            nochange= nochange+1

    else:
        if test0['Outputs Vader Score'][i]<=-0.05:
            flip.append('from neutral to negative')
            fromneutraltonegative = fromneutraltonegative+1
        
        elif test0['Outputs Vader Score'][i]>=0.05:
            flip.append('from neutral to positive')
            fromneutraltopositive = fromneutraltopositive+1
        else:
            flip.append('no change')
            nochange= nochange+1

# %%
test0['Flip Class'] = flip

# %%
test0
# Out:
#                                                                                                                                                        0  ...                 Flip Class
# 0     "(Bloomberg) -- The coronavirus came relatively late to Yemen, but even with advance notice it has still been ravaged by the disease."              ...  no change
# 1     "Morgan Stanley sees balanced risks to its estimate that consumption will fall at an annualized 41.4% rate in the second quarter."                  ...  from negative to positive
# 2     "[Sanctions] do no good to the Chinese economy and finance, so they do no good to the global and US economies, he added."                           ...  no change
# 3     "Further, Wall Street has continued to show a lack of confidence in the brand's ability to weather persistent challenges in North America."         ...  no change
# 4     "A spokesperson for Facebook Inc. said the company had removed the accounts identified by Strick on the grounds that they were promoting spam."     ...  no change
# ...                                                                                                                                               ...     ...        ...
# 2181  "Brazil's real dropped about 1.5% after a survey showed the country's service sector confidence in March plunged at its fastest rate on record."    ...  from positive to negative
# 2182  "Even the unprecedented aid from the Fed and Congress won't be nearly enough for households and businesses to weather a protracted downturn."       ...  from neutral to positive
# 2183  "But the WeChat ban order may be a bigger threat as there doesn't seem to be an obvious way out before the deadline."                               ...  no change
# 2184  "Microsoft Corp slipped 1.6% as its flagship cloud computing business Azure reported quarterly sales growth of under 50% for the first time ever."  ...  no change
# 2185  "Although profits continued to grow, the legal and regulatory scrutiny around the company clouded its future, and shareholders paid the price."     ...  from positive to negative
#
# [2186 rows x 7 columns]

# %%
test0[test0['BERT Cosine Similarity']>0.6]
# Out:
#                                                                                                                                                                                                                                                                0  ...                 Flip Class
# 4     "A spokesperson for Facebook Inc. said the company had removed the accounts identified by Strick on the grounds that they were promoting spam."                                                                                                             ...  no change
# 16    "Aiming to head off any panic, China's government took steps to shore up an economy hit by travel curbs and business shut-downs."                                                                                                                           ...  from negative to positive
# 25    "In China, every year has only 364 days; one day is forgotten, Taiwan President Tsai Ing-wen wrote on her Facebook page."                                                                                                                                   ...  no change
# 28    "COVID-19 has caused some logistical issues but these are robust numbers, demonstrating the underlying strength of the services that are driving these investments."                                                                                        ...  no change
# 61    "GAAP loss per share for the quarter was 48 cents, compared to a loss per share of 51 cents during the prior-year quarter."                                                                                                                                 ...  from negative to positive
# ...                                                                                                                           ...                                                                                                                                 ...                        ...
# 2129  "Link: https://www.zacks.com/commentary/1043877/airline-industrys-near-term-outlook-drab-due-to-coronavirus-woes The Zacks Airline industry houses companies engaged in the transport of passengers and cargoes to various destinations across the globe."  ...  from positive to negative
# 2173  "After all, he added, we are terribly Christian. Raised as a Roman Catholic, Bolsonaro has long courted the emerging Protestant hierarchy."                                                                                                                 ...  from negative to positive
# 2175  "In the opening month of the ongoing year, the health scare was only confined to China and was still considered an epidemic."                                                                                                                               ...  from negative to positive
# 2178  "INVESTMENT DILEMMA For some investors, the companies embody a dilemma that has dogged them at various times during the last decade."                                                                                                                       ...  from negative to positive
# 2183  "But the WeChat ban order may be a bigger threat as there doesn't seem to be an obvious way out before the deadline."                                                                                                                                       ...  no change
#
# [128 rows x 7 columns]

# %% [markdown]
# **SHOW PROPERTIES**

# %% [markdown]
# #split by words

# %%
word_num_list= []
for i in range(len(test0)):
  a_string= test0['predictions'][i]
  word_list = a_string.split()
  number_of_words = len(word_list)
  word_num_list.append(number_of_words)

test0['NumberofWords']=word_num_list

# %%
frequency = {}

# iterating over the list
for item in word_num_list:
   # checking the element in dictionary
   if item in frequency:
      # incrementing the counr
      frequency[item] += 1
   else:
      # initializing the count
      frequency[item] = 1

# printing the frequency
print(frequency)
# Out:
# {23: 584, 24: 373, 21: 306, 22: 542, 20: 133, 18: 14, 25: 133, 26: 40, 17: 4, 19: 48, 27: 7, 28: 1, 16: 1}

# %%
mintest0bcs=[]
medtest0bcs=[]
maxtest0bcs=[]
for i in range(len(test0)):
  if (test0['NumberofWords'][i] <= 20):
    mintest0bcs.append(test0['BERT Cosine Similarity'][i])
  elif (20 < test0['NumberofWords'][i] <= 25):
    medtest0bcs.append(test0['BERT Cosine Similarity'][i])
  elif (25< test0['NumberofWords'][i] ):
    maxtest0bcs.append(test0['BERT Cosine Similarity'][i])

# %%
properties('DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Min Number Of Words',mintest0bcs)
# Out:
# DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Min Number Of Words
# min is :
# 0.060315683484077454
# max is :
# 0.7593638896942139
# median is:
# 0.40207812190055847
# average is:
# 0.4057684187218547

# %%
properties('DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Med Number Of Words',medtest0bcs)
# Out:
# DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Med Number Of Words
# min is :
# 0.07385541498661041
# max is :
# 0.8260202407836914
# median is:
# 0.4167758822441101
# average is:
# 0.4157013087480553

# %%
properties('DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Max Number Of Words',maxtest0bcs)
# Out:
# DeleteandRetrive FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics for Max Number Of Words
# min is :
# 0.23436766862869263
# max is :
# 0.7428536415100098
# median is:
# 0.4194944500923157
# average is:
# 0.4244736808662613

# %% [markdown]
# **SHOW PROPERTIES**

# %%
print('from negative to positive')
print(fromnegativetopositive)
print('from negative to neutral')
print(fromnegativetoneutral)
print('from positive to negative')
print(frompositivetonegative) 
print('from positive to neutral')
print(frompositivetoneutral)
print('from neutral to negative')
print(fromneutraltonegative) 
print('from neutral to positive')
print(fromneutraltopositive)
print('no change')
print(nochange)

# %%
properties('DeleteOnly FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics',test0co)

# %%
properties('DeleteOnly FinancialPhaseBank Inputs VADER Score Statistics',comp_score_in_Fin)

# %%
properties('DeleteOnly yelp FinancialPhaseBank 69.epoch Outputs VADER Score Statistics',comp_score_out_Fin)

# %%
properties('DeleteOnly FinancialPhaseBank 69.epoch Diffirence VADER Score Statistics Bettween Input and Output',Fin_diff)

# %%
print('from negative to positive')
print(fromnegativetopositive)
print('from negative to neutral')
print(fromnegativetoneutral)
print('from positive to negative')
print(frompositivetonegative) 
print('from positive to neutral')
print(frompositivetoneutral)
print('from neutral to negative')
print(fromneutraltonegative) 
print('from neutral to positive')
print(fromneutraltopositive)
print('no change')
print(nochange)

# %%
properties('DeleteOnly FinancialPhaseBank 69.epoch Bert Cosine Similarities Statistics',test0co)

# %%
properties('DeleteOnly FinancialPhaseBank Inputs VADER Score Statistics',comp_score_in_Fin)

# %%
properties('DeleteOnly yelp FinancialPhaseBank 69.epoch Outputs VADER Score Statistics',comp_score_out_Fin)

# %%
properties('DeleteOnly FinancialPhaseBank 69.epoch Diffirence VADER Score Statistics Bettween Input and Output',Fin_diff)
